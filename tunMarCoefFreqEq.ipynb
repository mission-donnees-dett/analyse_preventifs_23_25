# %% [markdown]
# On veut créer un document qui extrait les formules des références prix du tableau de Fanny, et où l'on peut mettre une colonne des coéfficients pour chaque référence prix extraite, et aussi le nombre équipé et la fréquence totale. Ainsi, on pourra comparer les montants de 2023 et 2025 aux normatives de 2025 au niveau des prix.

# %%
# Importer les bibliothèques nécessaires
import re
import pandas as pd
from openpyxl import load_workbook
import requests
from io import BytesIO
import numpy as np

# Affichage complet dans pandas
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Télécharger le fichier Excel depuis l'URL
url = 'https://raw.githubusercontent.com/mission-donnees-dett/analyse_preventifs_23_25/main/Tunnels_Cout%20pre%CC%81ventif_13.06.2025%20(4).xlsx'
response = requests.get(url)
file_stream = BytesIO(response.content)

# Charger le fichier Excel avec openpyxl
wb = load_workbook(filename=file_stream, data_only=False)
ref_sheet = 'Préventifs_tunnels'
ref_ws = wb[ref_sheet]

# %%
# Liste des feuilles Excel des tunnels
tunnel_sheets = [
    'Boissy', 'Champigny', 'Guy Môquet', 'Moulin', 'Nogent',
    'Ambroise Paré', 'Belle-Rive', 'Chennevières', 'Fontenay', 'La Défense',
    'Nanterre Centre', 'Nanterre échangeur', 'Neuilly', 'Saint-Cloud', 'Sévines',
    'Bobigny', 'La Courneuve', 'Landy', 'Lumen-Norton', 'Taverny',
    'Antony', 'Fresnes', 'Bicêtre', 'Italie', 'Orly',
]

# Types de marchés recherchés
marches = ["Bâtiment", "Propreté", "ContReg", "Eclairage", "AEV", "Automate", "PAU/TSE", "MEC", "Onduleur", "Détection", "Ventilation", "Vidéo", "Pompage"]

# %%
# Obtenir la valeur de référence prix depuis l'onglet global 'Préventifs_tunnels'
def get_ref_prix(row_num):
    try:
        val = ref_ws[f"D{row_num}"].value
        return val if val else f"MISSING D{row_num}"
    except:
        return f"INVALID D{row_num}"

# %%
# Obtenir la valeur de référence prix depuis la feuille de référence
def get_ref_prix(row_num):
    try:
        val = ref_ws[f"D{row_num}"].value
        return val if val else f"MISSING D{row_num}"
    except:
        return f"INVALID D{row_num}"

# %% [markdown]
# Il faut lire les formules de la colonne G dans l'onglet de chaque tunnel maintenant.

# %%
# Extraire les détails d'une formule Excel
def extract_formula_details(formula):
    if re.match(r"^=\s*'?.+?!G\d+$", formula):
        return 'direct', [(formula.split('!G')[-1])], 1.0
    elif re.match(r"^=\(\s*'?.+?!G\d+\s*\+\s*'?.+?!G\d+\s*\)$", formula):
        return 'sum_2', re.findall(r"G(\d+)", formula), 1.0
    elif re.match(r"(?i)^=\s*SUM\(\s*'?.+?!G(\d+):G(\d+)\s*\)$", formula):
        match = re.search(r"G(\d+):G(\d+)", formula)
        if match:
            start, end = int(match.group(1)), int(match.group(2))
            return f"sum_{abs(end - start) + 1}", [str(i) for i in range(start, end + 1)], 1.0
    elif re.match(r"^=\(\s*'?.+?!G\d+\s*\+\s*'?.+?!G\d+\s*\)/\d+(\.\d+)?$", formula):
        return 'div_2', re.findall(r"G(\d+)", formula), 0.5
    elif re.match(r"^=\s*'?.+?!G\d+/\d+(\.\d+)?$", formula):
        return 'div_1', [re.findall(r"G(\d+)", formula)[0]], 0.5
    else:
        return 'unknown', [], 0

# %% [markdown]
# Les formules sont soit des sommes, soit des divisions, soit des références à des autres cellules dans une autre feuille; donc, il faut qu'on prend tout ça en compte quand on lit les formules.

# %%
# Résoudre une valeur de cellule Excel avec formules, récursivement
def resolve_cell_value(wb, ws, val, max_depth=5):
    sheet_name_map = {'Equipementspartunnel': 'Equipements par tunnel'}
    if max_depth <= 0:
        return f"Max recursion depth reached"
    if not isinstance(val, str) or not val.startswith('='):
        return val

    val_clean = val.lstrip('=').replace(' ', '')

    # Gestion des formules SUM
    match_sum = re.match(r"(?i)^SUM\(([A-Z]+\d+):([A-Z]+\d+)\)$", val_clean)
    if match_sum:
        col = re.match(r"([A-Z]+)", match_sum.group(1)).group(1)
        start_row = int(re.match(r"[A-Z]+(\d+)", match_sum.group(1)).group(1))
        end_row = int(re.match(r"[A-Z]+(\d+)", match_sum.group(2)).group(1))
        total = 0
        for r in range(start_row, end_row + 1):
            v = resolve_cell_value(wb, ws, ws[f"{col}{r}"].value, max_depth - 1)
            try:
                total += float(v)
            except:
                pass
        return total

    # Gestion des opérations entre cellules (mêmes ou autres feuilles)
    op_match = re.match(r"(?:'([^']+)')?!?([A-Z]+\d+)([\+\-\/])(?:'([^']+)')?!?([A-Z]+\d+)", val_clean)
    if op_match:
        sheet1, cell1, op, sheet2, cell2 = op_match.groups()
        sheet1 = sheet_name_map.get(sheet1, sheet1) if sheet1 else ws.title
        sheet2 = sheet_name_map.get(sheet2, sheet2) if sheet2 else ws.title
        val1 = resolve_cell_value(wb, wb[sheet1], wb[sheet1][cell1].value, max_depth - 1) if sheet1 in wb.sheetnames else 0
        val2 = resolve_cell_value(wb, wb[sheet2], wb[sheet2][cell2].value, max_depth - 1) if sheet2 in wb.sheetnames else 0
        try:
            val1, val2 = float(val1), float(val2)
            return val1 + val2 if op == '+' else val1 - val2 if op == '-' else val1 / val2 if val2 != 0 else 0
        except:
            return 0

    # Référence simple vers une autre cellule d'une autre feuille
    match_ref = re.match(r"'?([^']+)'?!([A-Z]+\d+)", val_clean)
    if match_ref:
        sheet_name, cell_ref = match_ref.groups()
        sheet_name = sheet_name_map.get(sheet_name, sheet_name)
        if sheet_name in wb.sheetnames:
            cell_val = wb[sheet_name][cell_ref].value
            return resolve_cell_value(wb, wb[sheet_name], cell_val, max_depth - 1)
        else:
            return f"MISSING SHEET {sheet_name}"

    # Références locales avec opérateurs
    match_local = re.match(r"([A-Z]+\d+)([\+\-\/])([A-Z]+\d+)", val_clean)
    if match_local:
        c1, op, c2 = match_local.groups()
        v1 = resolve_cell_value(wb, ws, ws[c1].value, max_depth - 1)
        v2 = resolve_cell_value(wb, ws, ws[c2].value, max_depth - 1)
        try:
            v1, v2 = float(v1), float(v2)
            return v1 + v2 if op == '+' else v1 - v2 if op == '-' else v1 / v2 if v2 != 0 else 0
        except:
            return 0

    return val

# %%
# Extraire les formules et valeurs depuis toutes les feuilles
all_rows = []

for tunnel in tunnel_sheets:
    ws = wb[tunnel]
    for row in ws.iter_rows(min_row=3, min_col=1, max_col=7):
        marche_cell, g_cell = row[0], row[6]
        if marche_cell.value not in marches or g_cell.data_type != 'f':
            continue

        marche = marche_cell.value
        formula = g_cell.value
        formula_type, row_refs, coeff = extract_formula_details(formula)
        freq_totale_val = resolve_cell_value(wb, ws, row[4].value)
        nbr_equipe_val = resolve_cell_value(wb, ws, row[5].value)
        try:
            nbr_equipe_val = float(nbr_equipe_val)
        except:
            nbr_equipe_val = 0

        if not row_refs:
            all_rows.append({
                'Tunnel': tunnel,
                'Marché': marche,
                'Référence prix': '',
                'Coefficient': coeff,
                'freq_totale': freq_totale_val,
                'nbr_equipe': nbr_equipe_val,
                'Source Cell': g_cell.coordinate,
                'Formula Type': formula_type
            })
            continue

        for i, ref_row in enumerate(row_refs):
            ref_prix = get_ref_prix(int(ref_row))
            all_rows.append({
                'Tunnel': tunnel,
                'Marché': marche,
                'Référence prix': ref_prix,
                'Coefficient': coeff if i == 0 else '',
                'freq_totale': freq_totale_val if i == 0 else '',
                'nbr_equipe': nbr_equipe_val if i == 0 else '',
                'Source Cell': g_cell.coordinate if i == 0 else '',
                'Formula Type': formula_type if i == 0 else ''
            })

# %%
# Créer le DataFrame final
tunnel_mar_prix_coefficient = pd.DataFrame(all_rows, columns=[
    'Tunnel', 'Marché', 'Référence prix', 'Coefficient',
    'freq_totale', 'nbr_equipe', 'Source Cell', 'Formula Type'
])

# Remplissage vers l'avant (comme forward-fill) des colonnes nécessaires --> ffill()
tunnel_mar_prix_coefficient['Source Cell'] = tunnel_mar_prix_coefficient['Source Cell'].replace('', np.nan).ffill()

# Remplacer les chaînes vides par NaN
cols_to_fill = ['Coefficient', 'freq_totale', 'nbr_equipe']
for col in cols_to_fill:
    tunnel_mar_prix_coefficient[col] = tunnel_mar_prix_coefficient[col].replace('', np.nan)

# Remplir les valeurs manquantes par groupe
def fill_group(group):
    for col in cols_to_fill:
        group[col] = group[col].ffill().bfill()
    return group

tunnel_mar_prix_coefficient = (
    tunnel_mar_prix_coefficient
    .groupby(['Tunnel', 'Source Cell'], dropna=False)
    .apply(fill_group)
    .reset_index(drop=True)
)
# Out:
# /var/folders/s1/1wg2rzvx4_ndhknnyblvg_j80000gn/T/ipykernel_89643/165483627.py:22: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   tunnel_mar_prix_coefficient

# %%
# Exporter le DataFrame nettoyé en CSV
#tunnel_mar_prix_coefficient.to_csv('tunMarCoefFreqEq.csv', index=False)

# %% [markdown]
# ---

# %%
coef_freq_df = pd.read_csv('https://raw.githubusercontent.com/mission-donnees-dett/analyse_preventifs_23_25/refs/heads/main/tunMarCoefFreqEq.csv')
prod_code_df = pd.read_csv('https://raw.githubusercontent.com/mission-donnees-dett/analyse_preventifs_23_25/refs/heads/main/prdp_prod_code_montants_designation_2324.csv', delimiter=';')

merged_df = coef_freq_df.merge(
    prod_code_df[['prod_code', 'prdp_code']],
    how='left',
    left_on='Référence prix',
    right_on='prod_code'
)

# Drop the extra 'prod_code' column if not needed
merged_df.drop(columns=['prod_code'], inplace=True)


merged_df.head(5)
# Out:
#    Tunnel    Marché Référence prix  Coefficient  freq_totale  nbr_equipe  \
# 0  Boissy  Bâtiment         VJE001          1.0          6.0         1.0
# 1  Boissy  Bâtiment         VJE002          1.0          6.0         1.0
# 2  Boissy  Bâtiment         VNE001          1.0          6.0         1.0
# 3  Boissy  Bâtiment         VNE002          1.0          6.0         1.0
# 4  Boissy  Bâtiment         MPE001          1.0          1.0         1.0
#
#   Source Cell Formula Type  prdp_code
# 0          G3        sum_2  BATCJE001
# 1          G3          NaN  BATCJE002
# 2          G4        sum_2  BATCNE001
# 3          G4          NaN  BATCNE002
# 4          G5        sum_2  BATMPE001

# %%
prevTun = pd.read_excel(url,sheet_name=ref_sheet)

corCdPrix=prevTun[[ 'Marché',  'Référence\nprix',       'Prix\nactuel']].set_index(['Marché',  'Référence\nprix'])
corCdPrix.columns=['prixAct']

tunMarPr=tunnel_mar_prix_coefficient.join(corCdPrix,on=['Marché',  'Référence prix'])

tunMarPr['nbFrCfPr']=tunMarPr['Coefficient']*tunMarPr['freq_totale']*tunMarPr['nbr_equipe']*tunMarPr['prixAct']
tunMarPrA=tunMarPr.groupby(['Marché', 'Tunnel',tunMarPr['Référence prix']])['nbFrCfPr'].sum()

tunMarPrA[1:100:10]
# Out:
# Marché    Tunnel              Référence prix
# AEV       Ambroise Paré       AEPB10             9010.28
#           Bicêtre             AEV08              1357.40
#           Chennevières        AEFB11             1417.44
#           Guy Môquet          AEPE20             6033.78
#           La Défense          AEPO10            30678.92
#           Moulin              AEPE20             6033.78
#           Nanterre échangeur  AEPO11            19251.36
#           Orly                AEV08               740.40
# Automate  Ambroise Paré       AUPR11              309.50
#           Belle-Rive          AUPR47              976.75
# Name: nbFrCfPr, dtype: float64

# %%
# Step 1: Prepare price data from prevTun
price_df = prevTun[['Marché', 'Référence\nprix', 'Prix\nactuel']].copy()
price_df.rename(columns={'Référence\nprix': 'Référence prix'}, inplace=True)

# Step 2: Merge merged_df with price_df on ['Marché', 'Référence prix']
merged_full = merged_df.merge(
    price_df,
    how='left',
    on=['Marché', 'Référence prix']
)

# Step 3: Calculate 'nbFrCfPr'
merged_full['nbFrCfPr'] = (
    merged_full['Coefficient'] *
    merged_full['freq_totale'] *
    merged_full['nbr_equipe'] *
    merged_full['Prix\nactuel']
)

# Step 4: Preview the result with both 'Référence prix' and 'prdp_code'
#merged_full[['Marché', 'Tunnel', 'Référence prix', 'prdp_code', 'Prix\nactuel', 'nbFrCfPr']]
merged_full.head()
# Out:
#    Tunnel    Marché Référence prix  Coefficient  freq_totale  nbr_equipe  \
# 0  Boissy  Bâtiment         VJE001          1.0          6.0         1.0
# 1  Boissy  Bâtiment         VJE002          1.0          6.0         1.0
# 2  Boissy  Bâtiment         VNE001          1.0          6.0         1.0
# 3  Boissy  Bâtiment         VNE002          1.0          6.0         1.0
# 4  Boissy  Bâtiment         MPE001          1.0          1.0         1.0
#
#   Source Cell Formula Type  prdp_code  Prix\nactuel  nbFrCfPr
# 0          G3        sum_2  BATCJE001         507.0    3042.0
# 1          G3          NaN  BATCJE002         507.0    3042.0
# 2          G4        sum_2  BATCNE001        1306.0    7836.0
# 3          G4          NaN  BATCNE002        1306.0    7836.0
# 4          G5        sum_2  BATMPE001        1407.0    1407.0

# %%
merged_full.groupby('Tunnel')['nbFrCfPr'].sum()
# Out:
# Tunnel
# Ambroise Paré         2.717113e+05
# Antony                2.270810e+05
# Belle-Rive            3.456943e+05
# Bicêtre               2.803526e+05
# Bobigny               3.021842e+05
# Boissy                1.915200e+05
# Champigny             2.996945e+05
# Chennevières          1.502285e+05
# Fontenay              1.860188e+05
# Fresnes               1.927496e+05
# Guy Môquet            2.135194e+05
# Italie                1.022971e+05
# La Courneuve          7.939366e+04
# La Défense            1.262256e+06
# Landy                 3.711187e+05
# Lumen-Norton          2.265802e+05
# Moulin                2.162775e+05
# Nanterre Centre       3.080085e+05
# Nanterre échangeur    5.178356e+05
# Neuilly               1.215444e+05
# Nogent                5.006444e+05
# Orly                  1.160372e+05
# Saint-Cloud           2.796484e+05
# Sévines               1.458621e+05
# Taverny               1.639986e+05
# Name: nbFrCfPr, dtype: float64

# %%
prdp_montants = prod_code_df.set_index('prdp_code')[
    ['montant_ht_2023', 'montant_ht_2024']
]


merged_full = merged_full.join(prdp_montants, on='prdp_code')

# %%
merged_full.head(50)
# Out:
#     Tunnel     Marché Référence prix  Coefficient  freq_totale  nbr_equipe  \
# 0   Boissy   Bâtiment         VJE001          1.0          6.0         1.0
# 1   Boissy   Bâtiment         VJE002          1.0          6.0         1.0
# 2   Boissy   Bâtiment         VNE001          1.0          6.0         1.0
# 3   Boissy   Bâtiment         VNE002          1.0          6.0         1.0
# 4   Boissy   Bâtiment         MPE001          1.0          1.0         1.0
# 5   Boissy   Bâtiment         MPE002          1.0          1.0         1.0
# 6   Boissy   Propreté         POL030          1.0          2.0         2.0
# 7   Boissy    ContReg         CRC106          1.0          1.0         1.0
# 8   Boissy    ContReg         CRC107          1.0          1.0         1.0
# 9   Boissy    ContReg         CRE110          1.0          1.0         1.0
# 10  Boissy    ContReg         CRC101          1.0          1.0         0.0
# 11  Boissy    ContReg         CRC102          1.0          1.0         0.0
# 12  Boissy    ContReg         CRC103          1.0          1.0         0.0
# 13  Boissy  Eclairage         ECPE05          1.0          2.0         2.0
# 14  Boissy  Eclairage         ECPE18          1.0          2.0         2.0
# 15  Boissy  Eclairage         ECPE66          1.0          0.4         2.0
# 16  Boissy  Eclairage         ECPE68          1.0          0.4         2.0
# 17  Boissy  Eclairage         ECPE69          1.0          0.4         2.0
# 18  Boissy        AEV         AEFE16          1.0          2.0         2.0
# 19  Boissy        AEV         AEPE26          1.0          2.0         2.0
# 20  Boissy        AEV          AEV08          1.0          1.0        32.0
# 21  Boissy   Automate         AUPR27          1.0          1.0         1.0
# 22  Boissy   Automate         AUPR28          1.0          1.0         1.0
# 23  Boissy   Automate         AUPR47          1.0          1.0         3.0
# 24  Boissy   Automate         AUPR48          1.0          1.0         9.0
# 25  Boissy    PAU/TSE       RAU-PE01          1.0          4.0         1.0
# 26  Boissy    PAU/TSE       TSE-PE01          1.0          4.0         1.0
# 27  Boissy        MEC            713          1.0          0.5         1.0
# 28  Boissy        MEC            717          1.0          0.5         1.0
# 29  Boissy        MEC            721          1.0          0.0         1.0
# 30  Boissy        MEC            733          1.0          0.5         1.0
# 31  Boissy        MEC            740          1.0          0.5         1.0
# 32  Boissy        MEC            747          1.0          0.0         1.0
# 33  Boissy        MEC            763          1.0          0.5         1.0
# 34  Boissy        MEC            768          1.0          0.5         1.0
# 35  Boissy        MEC            773          1.0          0.0         1.0
# 36  Boissy        MEC            783          1.0          1.0         1.0
# 37  Boissy        MEC            401          1.0          0.5         5.0
# 38  Boissy        MEC            402          1.0          0.5         5.0
# 39  Boissy   Onduleur         ONP001          1.0          1.0         0.0
# 39  Boissy   Onduleur         ONP001          1.0          1.0         0.0
# 40  Boissy   Onduleur         ONP001          1.0          1.0         0.0
# 40  Boissy   Onduleur         ONP001          1.0          1.0         0.0
# 41  Boissy   Onduleur         ONP002          1.0          1.0         0.0
# 41  Boissy   Onduleur         ONP002          1.0          1.0         0.0
# 42  Boissy   Onduleur         ONP002          1.0          1.0         0.0
# 42  Boissy   Onduleur         ONP002          1.0          1.0         0.0
# 43  Boissy   Onduleur         ONP003          1.0          1.0         1.0
# 43  Boissy   Onduleur         ONP003          1.0          1.0         1.0
# 44  Boissy   Onduleur         ONP003          1.0          1.0         1.0
#
#    Source Cell Formula Type  prdp_code  Prix\nactuel   nbFrCfPr  \
# 0           G3        sum_2  BATCJE001        507.00   3042.000
# 1           G3          NaN  BATCJE002        507.00   3042.000
# 2           G4        sum_2  BATCNE001       1306.00   7836.000
# 3           G4          NaN  BATCNE002       1306.00   7836.000
# 4           G5        sum_2  BATMPE001       1407.00   1407.000
# 5           G5          NaN  BATMPE002       1407.00   1407.000
# 6           G6       direct  PRPLTB030       8706.50  34826.000
# 7           G7       direct  CRGVPA106        486.45    486.450
# 8           G8       direct  CRGVPA107        864.80    864.800
# 9           G9       direct  CRGVIE110       2594.40   2594.400
# 10         G10       direct  CRGDLA101        648.60      0.000
# 11         G11       direct  CRGDLB102        864.80      0.000
# 12         G12       direct  CRGDLC103       1081.00      0.000
# 13         G13       direct  ECLNPE005        325.80   1303.200
# 14         G14       direct  ECLNEE018       3286.99  13147.960
# 15         G15        sum_3  ECLRSE066       1053.36    842.688
# 16         G15          NaN  ECLRSE068       2701.38   2161.104
# 17         G15          NaN  ECLRSE069       4247.45   3397.960
# 18         G16       direct  AEVEFE016        577.71   2310.840
# 19         G17       direct  AEVMPE026       1090.66   4362.640
# 20         G18       direct  AEVPLV008         61.70   1974.400
# 21         G19       direct  AUTPAB027        309.50    309.500
# 22         G20       direct  AUTPAR028       1111.64   1111.640
# 23         G21       direct  AUTPAM047        195.35    586.050
# 24         G22       direct  AUTPAR048         88.19    793.710
# 25         G23       direct  RTSPPE001        700.25   2801.000
# 26         G24       direct  RTSPTE001        359.87   1439.480
# 27         G25       direct        NaN       1897.94    948.970
# 28         G26       direct        NaN       3439.97   1719.985
# 29         G27       direct        NaN       5003.33      0.000
# 30         G28       direct        NaN       1334.55    667.275
# 31         G29       direct        NaN       2280.19   1140.095
# 32         G30       direct        NaN       1585.51      0.000
# 33         G31       direct        NaN       4403.54   2201.770
# 34         G32       direct        NaN       2957.30   1478.650
# 35         G33       direct        NaN       5333.49      0.000
# 36         G34       direct        NaN       2135.15   2135.150
# 37         G35       direct        NaN        469.67   1174.175
# 38         G36       direct        NaN        617.11   1542.775
# 39         G37       direct  ONDPOA001        304.01      0.000
# 39         G37       direct  ONDPOA001        304.01      0.000
# 40         G37       direct  ONDPOA001        304.01      0.000
# 40         G37       direct  ONDPOA001        304.01      0.000
# 41         G38       direct  ONDPOB002        337.95      0.000
# 41         G38       direct  ONDPOB002        337.95      0.000
# 42         G38       direct  ONDPOB002        337.95      0.000
# 42         G38       direct  ONDPOB002        337.95      0.000
# 43         G39       direct  ONDPOC003        371.88    371.880
# 43         G39       direct  ONDPOC003        371.88    371.880
# 44         G39       direct  ONDPOC003        371.88    371.880
#
#     montant_ht_2023  montant_ht_2024
# 0              0.00             0.00
# 1              0.00             0.00
# 2              0.00             0.00
# 3              0.00             0.00
# 4              0.00             0.00
# 5              0.00             0.00
# 6              0.00             0.00
# 7              0.00             0.00
# 8              0.00             0.00
# 9              0.00             0.00
# 10             0.00             0.00
# 11             0.00             0.00
# 12             0.00             0.00
# 13             0.00             0.00
# 14          6009.12          6147.32
# 15             0.00             0.00
# 16             0.00             0.00
# 17             0.00             0.00
# 18             0.00             0.00
# 19          4033.62          2039.74
# 20             0.00          1192.20
# 21             0.00           593.48
# 22             0.00          2131.62
# 23             0.00             0.00
# 24             0.00             0.00
# 25             0.00          2010.30
# 26           344.37          1033.11
# 27              NaN              NaN
# 28              NaN              NaN
# 29              NaN              NaN
# 30              NaN              NaN
# 31              NaN              NaN
# 32              NaN              NaN
# 33              NaN              NaN
# 34              NaN              NaN
# 35              NaN              NaN
# 36              NaN              NaN
# 37              NaN              NaN
# 38              NaN              NaN
# 39             0.00          7904.26
# 39          4939.52             0.00
# 40             0.00          7904.26
# 40          4939.52             0.00
# 41             0.00          5745.15
# 41         10945.28             0.00
# 42             0.00          5745.15
# 42         10945.28             0.00
# 43             0.00          5950.08
# 43          7203.00             0.00
# 44             0.00          5950.08

# %%
merged_full = merged_full.drop_duplicates(
    subset=['prdp_code', 'montant_ht_2023', 'montant_ht_2024']
)

# %%
merged_full
# Out:
#                   Tunnel       Marché Référence prix  Coefficient  \
# 0                 Boissy     Bâtiment         VJE001          1.0
# 1                 Boissy     Bâtiment         VJE002          1.0
# 2                 Boissy     Bâtiment         VNE001          1.0
# 3                 Boissy     Bâtiment         VNE002          1.0
# 4                 Boissy     Bâtiment         MPE001          1.0
# 5                 Boissy     Bâtiment         MPE002          1.0
# 6                 Boissy     Propreté         POL030          1.0
# 7                 Boissy      ContReg         CRC106          1.0
# 8                 Boissy      ContReg         CRC107          1.0
# 9                 Boissy      ContReg         CRE110          1.0
# 10                Boissy      ContReg         CRC101          1.0
# 11                Boissy      ContReg         CRC102          1.0
# 12                Boissy      ContReg         CRC103          1.0
# 13                Boissy    Eclairage         ECPE05          1.0
# 14                Boissy    Eclairage         ECPE18          1.0
# 15                Boissy    Eclairage         ECPE66          1.0
# 16                Boissy    Eclairage         ECPE68          1.0
# 17                Boissy    Eclairage         ECPE69          1.0
# 18                Boissy          AEV         AEFE16          1.0
# 19                Boissy          AEV         AEPE26          1.0
# 20                Boissy          AEV          AEV08          1.0
# 21                Boissy     Automate         AUPR27          1.0
# 22                Boissy     Automate         AUPR28          1.0
# 23                Boissy     Automate         AUPR47          1.0
# 24                Boissy     Automate         AUPR48          1.0
# 25                Boissy      PAU/TSE       RAU-PE01          1.0
# 26                Boissy      PAU/TSE       TSE-PE01          1.0
# 27                Boissy          MEC            713          1.0
# 39                Boissy     Onduleur         ONP001          1.0
# 39                Boissy     Onduleur         ONP001          1.0
# 41                Boissy     Onduleur         ONP002          1.0
# 41                Boissy     Onduleur         ONP002          1.0
# 43                Boissy     Onduleur         ONP003          1.0
# 43                Boissy     Onduleur         ONP003          1.0
# 45                Boissy     Onduleur         ONP004          1.0
# 45                Boissy     Onduleur         ONP004          1.0
# 47                Boissy     Onduleur         ONP005          1.0
# 47                Boissy     Onduleur         ONP005          1.0
# 49                Boissy    Détection         DEP017          1.0
# 49                Boissy    Détection         DEP017          1.0
# 51                Boissy    Détection         DEP027          1.0
# 52                Boissy    Détection         DEP100          1.0
# 52                Boissy    Détection         DEP100          1.0
# 54                Boissy    Détection         DEP200          1.0
# 54                Boissy    Détection         DEP200          1.0
# 56                Boissy    Détection         DEP201          1.0
# 56                Boissy    Détection         DEP201          1.0
# 58                Boissy    Détection         DEP202          1.0
# 58                Boissy    Détection         DEP202          1.0
# 60                Boissy    Détection         DEP203          1.0
# 60                Boissy    Détection         DEP203          1.0
# 62                Boissy    Détection         DEP204          1.0
# 63                Boissy    Détection         DEP204          1.0
# 64                Boissy    Détection         DEP205          1.0
# 65                Boissy    Détection         DEP206          1.0
# 65                Boissy    Détection         DEP206          1.0
# 67                Boissy  Ventilation         VPE204          1.0
# 67                Boissy  Ventilation         VPE204          1.0
# 68                Boissy  Ventilation         VPT300          1.0
# 68                Boissy  Ventilation         VPT300          1.0
# 69                Boissy  Ventilation         VPT301          1.0
# 69                Boissy  Ventilation         VPT301          1.0
# 70                Boissy  Ventilation         VPT302          1.0
# 71                Boissy  Ventilation         VPT304          1.0
# 72                Boissy  Ventilation         VPT305          1.0
# 74                Boissy        Vidéo      VI MP 345          1.0
# 74                Boissy        Vidéo      VI MP 345          1.0
# 75                Boissy        Vidéo      VI MP 422          1.0
# 75                Boissy        Vidéo      VI MP 422          1.0
# 76                Boissy      Pompage         INP205          1.0
# 77                Boissy      Pompage         POP208          1.0
# 78                Boissy      Pompage         POE600          1.0
# 79                Boissy      Pompage         POE600          1.0
# 79                Boissy      Pompage         POE600          1.0
# 81                Boissy      Pompage         POE208          1.0
# 82                Boissy      Pompage         INP500          1.0
# 82                Boissy      Pompage         INP500          1.0
# 84                Boissy      Pompage         INP600          1.0
# 84                Boissy      Pompage         INP600          1.0
# 86                Boissy      Pompage         INP700          1.0
# 86                Boissy      Pompage         INP700          1.0
# 88                Boissy      Pompage         INP800          1.0
# 89                Boissy      Pompage         INP900          1.0
# 90                Boissy      Pompage         INP901          1.0
# 91             Champigny     Bâtiment         VJE003          1.0
# 92             Champigny     Bâtiment         VJE004          1.0
# 93             Champigny     Bâtiment         VNE003          1.0
# 94             Champigny     Bâtiment         VNE004          1.0
# 95             Champigny     Bâtiment         MPE003          1.0
# 96             Champigny     Bâtiment         MPE004          1.0
# 97             Champigny     Propreté         POL015          1.0
# 100            Champigny      ContReg         CRE103          1.0
# 101            Champigny      ContReg         CRE104          1.0
# 105            Champigny    Eclairage         ECPE03          1.0
# 106            Champigny    Eclairage         ECPE14          1.0
# 107            Champigny    Eclairage         ECPE58          1.0
# 108            Champigny    Eclairage         ECPE60          1.0
# 109            Champigny    Eclairage         ECPE61          1.0
# 110            Champigny          AEV         AEFE12          1.0
# 111            Champigny          AEV         AEPE22          1.0
# 113            Champigny     Automate         AUPR29          1.0
# 114            Champigny     Automate         AUPR30          1.0
# 117            Champigny      PAU/TSE       RAU-PE02          1.0
# 118            Champigny      PAU/TSE       TSE-PE02          1.0
# 141            Champigny    Détection         DEP015          1.0
# 141            Champigny    Détection         DEP015          1.0
# 159            Champigny  Ventilation         VPE201          1.0
# 159            Champigny  Ventilation         VPE201          1.0
# 165            Champigny        Vidéo      VI MP 101          1.0
# 165            Champigny        Vidéo      VI MP 101          1.0
# 166            Champigny        Vidéo      VI MP 301          1.0
# 166            Champigny        Vidéo      VI MP 301          1.0
# 167            Champigny        Vidéo      VI MP 400          1.0
# 167            Champigny        Vidéo      VI MP 400          1.0
# 168            Champigny      Pompage         INP203          1.0
# 168            Champigny      Pompage         INP203          1.0
# 182           Guy Môquet     Bâtiment         VJE005          1.0
# 183           Guy Môquet     Bâtiment         VJE006          1.0
# 184           Guy Môquet     Bâtiment         VNE005          1.0
# 185           Guy Môquet     Bâtiment         VNE006          1.0
# 186           Guy Môquet     Bâtiment         MPE005          1.0
# 187           Guy Môquet     Bâtiment         MPE006          1.0
# 188           Guy Môquet     Propreté         POL016          1.0
# 191           Guy Môquet      ContReg         CRE105          1.0
# 192           Guy Môquet      ContReg         CRE106          1.0
# 196           Guy Môquet    Eclairage         ECPE01          1.0
# 197           Guy Môquet    Eclairage         ECPE10          1.0
# 198           Guy Môquet    Eclairage         ECPE50          1.0
# 199           Guy Môquet    Eclairage         ECPE54          1.0
# 200           Guy Môquet    Eclairage         ECPE56          1.0
# 201           Guy Môquet          AEV         AEFE10          1.0
# 202           Guy Môquet          AEV         AEPE20          1.0
# 204           Guy Môquet     Automate         AUPR31          1.0
# 205           Guy Môquet     Automate         AUPR32          1.0
# 208           Guy Môquet      PAU/TSE       RAU-PE04          1.0
# 209           Guy Môquet      PAU/TSE       TSE-PE04          1.0
# 231           Guy Môquet    Détection         DEP016          1.0
# 231           Guy Môquet    Détection         DEP016          1.0
# 249           Guy Môquet  Ventilation         VPE202          1.0
# 249           Guy Môquet  Ventilation         VPE202          1.0
# 255           Guy Môquet        Vidéo      VI MP 103          1.0
# 255           Guy Môquet        Vidéo      VI MP 103          1.0
# 256           Guy Môquet        Vidéo      VI MP 303          1.0
# 256           Guy Môquet        Vidéo      VI MP 303          1.0
# 258           Guy Môquet      Pompage         INP201          1.0
# 258           Guy Môquet      Pompage         INP201          1.0
# 339               Moulin  Ventilation         VPE203          1.0
# 339               Moulin  Ventilation         VPE203          1.0
# 348               Moulin      Pompage         INP204          1.0
# 348               Moulin      Pompage         INP204          1.0
# 362               Nogent     Bâtiment         VJE007          1.0
# 363               Nogent     Bâtiment         VJE008          1.0
# 364               Nogent     Bâtiment         VNE007          1.0
# 365               Nogent     Bâtiment         VNE008          1.0
# 366               Nogent     Bâtiment         MPE007          1.0
# 367               Nogent     Bâtiment         MPE008          1.0
# 368               Nogent     Propreté         POL014          1.0
# 371               Nogent      ContReg         CRE101          1.0
# 372               Nogent      ContReg         CRE102          1.0
# 376               Nogent    Eclairage         ECPE04          1.0
# 377               Nogent    Eclairage         ECPE16          1.0
# 378               Nogent    Eclairage         ECPE62          1.0
# 379               Nogent    Eclairage         ECPE64          1.0
# 380               Nogent    Eclairage         ECPE65          1.0
# 381               Nogent          AEV         AEFE14          1.0
# 382               Nogent          AEV         AEPE24          1.0
# 384               Nogent     Automate         AUPR33          1.0
# 385               Nogent     Automate         AUPR34          1.0
# 388               Nogent      PAU/TSE       RAU-PE03          1.0
# 389               Nogent      PAU/TSE       TSE-PE03          1.0
# 412               Nogent    Détection         DEP014          1.0
# 412               Nogent    Détection         DEP014          1.0
# 430               Nogent  Ventilation         VPE200          1.0
# 430               Nogent  Ventilation         VPE200          1.0
# 436               Nogent        Vidéo      VI MP 105          1.0
# 436               Nogent        Vidéo      VI MP 105          1.0
# 437               Nogent        Vidéo      VI MP 305          1.0
# 437               Nogent        Vidéo      VI MP 305          1.0
# 438               Nogent        Vidéo      VI MP 402          1.0
# 438               Nogent        Vidéo      VI MP 402          1.0
# 451        Ambroise Paré     Bâtiment         VJO001          1.0
# 452        Ambroise Paré     Bâtiment         VJO002          1.0
# 453        Ambroise Paré     Bâtiment         VNO001          1.0
# 454        Ambroise Paré     Bâtiment         VNO002          1.0
# 455        Ambroise Paré     Bâtiment         MPO001          1.0
# 456        Ambroise Paré     Bâtiment         MPO002          1.0
# 457        Ambroise Paré     Propreté         POL004          1.0
# 460        Ambroise Paré      ContReg         CRO116          1.0
# 461        Ambroise Paré      ContReg         CRO117          1.0
# 462        Ambroise Paré      ContReg         CRO118          1.0
# 466        Ambroise Paré    Eclairage         ECPB01          1.0
# 467        Ambroise Paré    Eclairage         ECPB10          1.0
# 468        Ambroise Paré    Eclairage         ECPB51          1.0
# 469        Ambroise Paré    Eclairage         ECPB52          1.0
# 470        Ambroise Paré    Eclairage         ECPB53          1.0
# 471        Ambroise Paré          AEV         AEFB10          1.0
# 472        Ambroise Paré          AEV         AEPB10          1.0
# 474        Ambroise Paré     Automate         AUPR11          1.0
# 475        Ambroise Paré     Automate         AUPR12          1.0
# 478        Ambroise Paré      PAU/TSE       RAU-PO09          1.0
# 479        Ambroise Paré      PAU/TSE       TSE-PO09          1.0
# 502        Ambroise Paré    Détection         DEP004          1.0
# 502        Ambroise Paré    Détection         DEP004          1.0
# 520        Ambroise Paré  Ventilation         VPB203          1.0
# 520        Ambroise Paré  Ventilation         VPB203          1.0
# 526        Ambroise Paré        Vidéo      VI MP 129          1.0
# 526        Ambroise Paré        Vidéo      VI MP 129          1.0
# 527        Ambroise Paré        Vidéo      VI MP 329          1.0
# 527        Ambroise Paré        Vidéo      VI MP 329          1.0
# 528        Ambroise Paré        Vidéo      VI MP 414          1.0
# 528        Ambroise Paré        Vidéo      VI MP 414          1.0
# 529        Ambroise Paré      Pompage         INP311          1.0
# 529        Ambroise Paré      Pompage         INP311          1.0
# 530        Ambroise Paré      Pompage         INP311          1.0
# 530        Ambroise Paré      Pompage         INP311          1.0
# 531        Ambroise Paré      Pompage         POP322          1.0
# 535        Ambroise Paré      Pompage         POE322          1.0
# 535        Ambroise Paré      Pompage         POE322          1.0
# 546           Belle-Rive     Bâtiment         VJO008          1.0
# 547           Belle-Rive     Bâtiment         VJO009          1.0
# 548           Belle-Rive     Bâtiment         VNO008          1.0
# 549           Belle-Rive     Bâtiment         VNO009          1.0
# 550           Belle-Rive     Bâtiment         MPO008          1.0
# 551           Belle-Rive     Bâtiment         MPO009          1.0
# 552           Belle-Rive     Propreté         POL005          1.0
# 555           Belle-Rive      ContReg         CRO113          1.0
# 556           Belle-Rive      ContReg         CRO114          1.0
# 557           Belle-Rive      ContReg         CRO115          1.0
# 561           Belle-Rive    Eclairage         ECPB05          1.0
# 562           Belle-Rive    Eclairage         ECPB20          1.0
# 563           Belle-Rive    Eclairage         ECPB66          1.0
# 564           Belle-Rive    Eclairage         ECPB67          1.0
# 565           Belle-Rive    Eclairage         ECPB68          1.0
# 566           Belle-Rive          AEV         AEFB14          1.0
# 567           Belle-Rive          AEV         AEPB14          1.0
# 569           Belle-Rive     Automate         AUPR13          1.0
# 570           Belle-Rive     Automate         AUPR14          1.0
# 573           Belle-Rive      PAU/TSE       RAU-PO08          1.0
# 574           Belle-Rive      PAU/TSE       TSE-PO08          1.0
# 597           Belle-Rive    Détection         DEP005          1.0
# 597           Belle-Rive    Détection         DEP005          1.0
# 615           Belle-Rive  Ventilation         VPO200          1.0
# 615           Belle-Rive  Ventilation         VPO200          1.0
# 621           Belle-Rive        Vidéo      VI MP 125          1.0
# 621           Belle-Rive        Vidéo      VI MP 125          1.0
# 622           Belle-Rive        Vidéo      VI MP 325          1.0
# 622           Belle-Rive        Vidéo      VI MP 325          1.0
# 623           Belle-Rive        Vidéo      VI MP 412          1.0
# 623           Belle-Rive        Vidéo      VI MP 412          1.0
# 624           Belle-Rive      Pompage         INP301          1.0
# 624           Belle-Rive      Pompage         INP301          1.0
# 626           Belle-Rive      Pompage         POP319          1.0
# 627           Belle-Rive      Pompage         POP320          1.0
# 628           Belle-Rive      Pompage         POP321          1.0
# 632           Belle-Rive      Pompage         POE319          1.0
# 632           Belle-Rive      Pompage         POE319          1.0
# 634           Belle-Rive      Pompage         POE320          1.0
# 634           Belle-Rive      Pompage         POE320          1.0
# 636           Belle-Rive      Pompage         POE321          1.0
# 636           Belle-Rive      Pompage         POE321          1.0
# 647         Chennevières     Bâtiment         VJO003          1.0
# 648         Chennevières     Bâtiment         VNO003          1.0
# 649         Chennevières     Bâtiment         MPO003          1.0
# 650         Chennevières     Propreté         POL001          1.0
# 653         Chennevières      ContReg         CRO123          1.0
# 657         Chennevières    Eclairage         ECPB02          1.0
# 658         Chennevières    Eclairage         ECPB12          1.0
# 659         Chennevières    Eclairage         ECPB54          1.0
# 660         Chennevières    Eclairage         ECPB55          1.0
# 661         Chennevières    Eclairage         ECPB56          1.0
# 662         Chennevières          AEV         AEFB11          1.0
# 663         Chennevières          AEV         AEPB11          1.0
# 665         Chennevières     Automate         AUPR15          1.0
# 666         Chennevières     Automate         AUPR16          1.0
# 669         Chennevières      PAU/TSE       RAU-PO06          1.0
# 670         Chennevières      PAU/TSE       TSE-PO06          1.0
# 693         Chennevières    Détection         DEP001          1.0
# 693         Chennevières    Détection         DEP001          1.0
# 711         Chennevières  Ventilation         VPB200          1.0
# 717         Chennevières        Vidéo      VI MP 135          1.0
# 717         Chennevières        Vidéo      VI MP 135          1.0
# 718         Chennevières        Vidéo      VI MP 335          1.0
# 718         Chennevières        Vidéo      VI MP 335          1.0
# 719         Chennevières        Vidéo      VI MP 417          1.0
# 719         Chennevières        Vidéo      VI MP 417          1.0
# 720         Chennevières      Pompage         INP304          1.0
# 720         Chennevières      Pompage         INP304          1.0
# 734             Fontenay     Bâtiment         VJO004          1.0
# 735             Fontenay     Bâtiment         VJO005          1.0
# 736             Fontenay     Bâtiment         VNO004          1.0
# 737             Fontenay     Bâtiment         VNO005          1.0
# 738             Fontenay     Bâtiment         MPO004          1.0
# 739             Fontenay     Bâtiment         MPO005          1.0
# 740             Fontenay     Propreté         POL002          1.0
# 743             Fontenay      ContReg         CRO122          1.0
# 747             Fontenay    Eclairage         ECPB03          1.0
# 748             Fontenay    Eclairage         ECPB14          1.0
# 749             Fontenay    Eclairage         ECPB57          1.0
# 750             Fontenay    Eclairage         ECPB58          1.0
# 751             Fontenay    Eclairage         ECPB59          1.0
# 752             Fontenay          AEV         AEFB12          1.0
# 753             Fontenay          AEV         AEPB12          1.0
# 755             Fontenay     Automate         AUPR17          1.0
# 756             Fontenay     Automate         AUPR18          1.0
# 759             Fontenay      PAU/TSE       RAU-PO07          1.0
# 760             Fontenay      PAU/TSE       TSE-PO07          1.0
# 783             Fontenay    Détection         DEP002          1.0
# 783             Fontenay    Détection         DEP002          1.0
# 801             Fontenay  Ventilation         VPB201          1.0
# 807             Fontenay        Vidéo      VI MP 131          1.0
# 808             Fontenay        Vidéo      VI MP 331          1.0
# 809             Fontenay        Vidéo      VI MP 415          1.0
# 810             Fontenay      Pompage         INP306          1.0
# 823           La Défense     Bâtiment         VJO010          1.0
# 824           La Défense     Bâtiment         VJO011          1.0
# 825           La Défense     Bâtiment         VNO010          1.0
# 826           La Défense     Bâtiment         VNO011          1.0
# 827           La Défense     Bâtiment         MPO010          1.0
# 828           La Défense     Bâtiment         MPO011          1.0
# 829           La Défense     Propreté         POL007          1.0
# 832           La Défense      ContReg         CRS106          1.0
# 836           La Défense    Eclairage         ECPO01          1.0
# 837           La Défense    Eclairage         ECPO02          1.0
# 838           La Défense    Eclairage         ECPO10          1.0
# 839           La Défense    Eclairage         ECPO12          1.0
# 840           La Défense    Eclairage         ECPO50          1.0
# 841           La Défense    Eclairage         ECPO51          1.0
# 842           La Défense    Eclairage         ECPO52          1.0
# 843           La Défense    Eclairage         ECPO53          1.0
# 844           La Défense    Eclairage         ECPO54          1.0
# 845           La Défense    Eclairage         ECPO55          1.0
# 846           La Défense          AEV         AEFO10          1.0
# 847           La Défense          AEV         AEFO11          1.0
# 848           La Défense          AEV         AEPO10          1.0
# 849           La Défense          AEV         AEPO11          1.0
# 851           La Défense     Automate         AUPR03          1.0
# 852           La Défense     Automate         AUPR04          1.0
# 855           La Défense      PAU/TSE       RAU-PO01          1.0
# 856           La Défense      PAU/TSE       TSE-PO01          1.0
# 889           La Défense    Détection         DEP006          1.0
# 889           La Défense    Détection         DEP006          1.0
# 892           La Défense    Détection         DEP103          1.0
# 906           La Défense  Ventilation         VPO201          1.0
# 906           La Défense  Ventilation         VPO201          1.0
# 912           La Défense        Vidéo      VI MP 123          1.0
# 912           La Défense        Vidéo      VI MP 123          1.0
# 913           La Défense        Vidéo      VI MP 323          1.0
# 913           La Défense        Vidéo      VI MP 323          1.0
# 914           La Défense        Vidéo      VI MP 411          1.0
# 914           La Défense        Vidéo      VI MP 411          1.0
# 915           La Défense      Pompage         INP302          1.0
# 915           La Défense      Pompage         INP302          1.0
# 917           La Défense      Pompage         POP312          1.0
# 917           La Défense      Pompage         POP312          1.0
# 919           La Défense      Pompage         POP313          1.0
# 919           La Défense      Pompage         POP313          1.0
# 924           La Défense      Pompage         POE312          1.0
# 924           La Défense      Pompage         POE312          1.0
# 926           La Défense      Pompage         POE313          1.0
# 926           La Défense      Pompage         POE313          1.0
# 937      Nanterre Centre     Bâtiment         VJO006          1.0
# 938      Nanterre Centre     Bâtiment         VJO007          1.0
# 939      Nanterre Centre     Bâtiment         VNO006          1.0
# 940      Nanterre Centre     Bâtiment         VNO007          1.0
# 941      Nanterre Centre     Bâtiment         MPO006          1.0
# 942      Nanterre Centre     Bâtiment         MPO007          1.0
# 943      Nanterre Centre     Propreté         POL006          1.0
# 946      Nanterre Centre      ContReg         CRO103          1.0
# 947      Nanterre Centre      ContReg         CRO104          1.0
# 948      Nanterre Centre      ContReg         CRO105          1.0
# 949      Nanterre Centre      ContReg         CRO106          1.0
# 950      Nanterre Centre      ContReg         CRO107          1.0
# 951      Nanterre Centre      ContReg         CRO108          1.0
# 952      Nanterre Centre      ContReg         CRO109          1.0
# 953      Nanterre Centre      ContReg         CRO110          1.0
# 954      Nanterre Centre      ContReg         CRO111          1.0
# 955      Nanterre Centre      ContReg         CRO112          1.0
# 959      Nanterre Centre    Eclairage         ECPO03          1.0
# 960      Nanterre Centre    Eclairage         ECPO04          1.0
# 961      Nanterre Centre    Eclairage         ECPO14          1.0
# 962      Nanterre Centre    Eclairage         ECPO16          1.0
# 969      Nanterre Centre          AEV         AEFO12          1.0
# 970      Nanterre Centre          AEV         AEFO13          1.0
# 971      Nanterre Centre          AEV         AEPO12          1.0
# 972      Nanterre Centre          AEV         AEPO13          1.0
# 974      Nanterre Centre     Automate         AUPR05          1.0
# 975      Nanterre Centre     Automate         AUPR06          1.0
# 978      Nanterre Centre      PAU/TSE       RAU-PO03          1.0
# 979      Nanterre Centre      PAU/TSE       TSE-PO03          1.0
# 1002     Nanterre Centre    Détection         DEP008          1.0
# 1002     Nanterre Centre    Détection         DEP008          1.0
# 1005     Nanterre Centre    Détection         DEP101          1.0
# 1005     Nanterre Centre    Détection         DEP101          1.0
# 1026     Nanterre Centre        Vidéo      VI MP 121          1.0
# 1026     Nanterre Centre        Vidéo      VI MP 121          1.0
# 1027     Nanterre Centre        Vidéo      VI MP 321          1.0
# 1027     Nanterre Centre        Vidéo      VI MP 321          1.0
# 1028     Nanterre Centre        Vidéo      VI MP 410          1.0
# 1028     Nanterre Centre        Vidéo      VI MP 410          1.0
# 1029     Nanterre Centre      Pompage         INP307          1.0
# 1029     Nanterre Centre      Pompage         INP307          1.0
# 1080  Nanterre échangeur     Automate         AUPR07          1.0
# 1081  Nanterre échangeur     Automate         AUPR08          1.0
# 1084  Nanterre échangeur      PAU/TSE       RAU-PO02          1.0
# 1085  Nanterre échangeur      PAU/TSE       TSE-PO02          1.0
# 1108  Nanterre échangeur    Détection         DEP007          1.0
# 1108  Nanterre échangeur    Détection         DEP007          1.0
# 1133  Nanterre échangeur        Vidéo      VI MP 346          1.0
# 1133  Nanterre échangeur        Vidéo      VI MP 346          1.0
# 1134  Nanterre échangeur        Vidéo      VI MP 423          1.0
# 1135  Nanterre échangeur      Pompage         INP305          1.0
# 1135  Nanterre échangeur      Pompage         INP305          1.0
# 1137  Nanterre échangeur      Pompage         POP307          1.0
# 1137  Nanterre échangeur      Pompage         POP307          1.0
# 1139  Nanterre échangeur      Pompage         POP308          1.0
# 1139  Nanterre échangeur      Pompage         POP308          1.0
# 1141  Nanterre échangeur      Pompage         POP309          1.0
# 1141  Nanterre échangeur      Pompage         POP309          1.0
# 1143  Nanterre échangeur      Pompage         POP310          1.0
# 1143  Nanterre échangeur      Pompage         POP310          1.0
# 1148  Nanterre échangeur      Pompage         POE307          1.0
# 1148  Nanterre échangeur      Pompage         POE307          1.0
# 1150  Nanterre échangeur      Pompage         POE308          1.0
# 1150  Nanterre échangeur      Pompage         POE308          1.0
# 1152  Nanterre échangeur      Pompage         POE309          1.0
# 1152  Nanterre échangeur      Pompage         POE309          1.0
# 1154  Nanterre échangeur      Pompage         POE310          1.0
# 1154  Nanterre échangeur      Pompage         POE310          1.0
# 1171             Neuilly     Propreté         POL008          1.0
# 1174             Neuilly      ContReg         CRO102          1.0
# 1178             Neuilly    Eclairage         ECPO06          1.0
# 1179             Neuilly    Eclairage         ECPO20          1.0
# 1180             Neuilly    Eclairage         ECPO59          1.0
# 1181             Neuilly    Eclairage         ECPO60          1.0
# 1182             Neuilly    Eclairage         ECPO61          1.0
# 1183             Neuilly          AEV         AEFO16          1.0
# 1184             Neuilly          AEV         AEPO16          1.0
# 1186             Neuilly     Automate         AUPR01          1.0
# 1187             Neuilly     Automate         AUPR02          1.0
# 1190             Neuilly      PAU/TSE       RAU-PO04          1.0
# 1191             Neuilly      PAU/TSE       TSE-PO04          1.0
# 1214             Neuilly    Détection         DEP009          1.0
# 1214             Neuilly    Détection         DEP009          1.0
# 1232             Neuilly  Ventilation         VPO202          1.0
# 1232             Neuilly  Ventilation         VPO202          1.0
# 1238             Neuilly        Vidéo      VI MP 117          1.0
# 1238             Neuilly        Vidéo      VI MP 117          1.0
# 1239             Neuilly        Vidéo      VI MP 317          1.0
# 1239             Neuilly        Vidéo      VI MP 317          1.0
# 1240             Neuilly        Vidéo      VI MP 408          1.0
# 1240             Neuilly        Vidéo      VI MP 408          1.0
# 1259         Saint-Cloud     Propreté         POL003          1.0
# 1262         Saint-Cloud      ContReg         CRO119          1.0
# 1263         Saint-Cloud      ContReg         CRO120          1.0
# 1264         Saint-Cloud      ContReg         CRO121          1.0
# 1268         Saint-Cloud    Eclairage         ECPB04          1.0
# 1269         Saint-Cloud    Eclairage         ECPB16          1.0
# 1270         Saint-Cloud    Eclairage         ECPB60          1.0
# 1271         Saint-Cloud    Eclairage         ECPB61          1.0
# 1272         Saint-Cloud    Eclairage         ECPB62          1.0
# 1273         Saint-Cloud    Eclairage         ECPB63          1.0
# 1274         Saint-Cloud    Eclairage         ECPB64          1.0
# 1275         Saint-Cloud    Eclairage         ECPB65          1.0
# 1276         Saint-Cloud          AEV         AEFB13          1.0
# 1277         Saint-Cloud          AEV         AEPB13          1.0
# 1279         Saint-Cloud     Automate         AUPR19          1.0
# 1280         Saint-Cloud     Automate         AUPR20          1.0
# 1283         Saint-Cloud      PAU/TSE       RAU-PO10          1.0
# 1284         Saint-Cloud      PAU/TSE       TSE-PO10          1.0
# 1307         Saint-Cloud    Détection         DEP003          1.0
# 1307         Saint-Cloud    Détection         DEP003          1.0
# 1325         Saint-Cloud  Ventilation         VPB202          1.0
# 1325         Saint-Cloud  Ventilation         VPB202          1.0
# 1331         Saint-Cloud        Vidéo      VI MP 127          1.0
# 1331         Saint-Cloud        Vidéo      VI MP 127          1.0
# 1332         Saint-Cloud        Vidéo      VI MP 327          1.0
# 1332         Saint-Cloud        Vidéo      VI MP 327          1.0
# 1333         Saint-Cloud        Vidéo      VI MP 413          1.0
# 1333         Saint-Cloud        Vidéo      VI MP 413          1.0
# 1334         Saint-Cloud      Pompage         INP310          1.0
# 1334         Saint-Cloud      Pompage         INP310          1.0
# 1336         Saint-Cloud      Pompage         POP324          1.0
# 1340         Saint-Cloud      Pompage         POE324          1.0
# 1340         Saint-Cloud      Pompage         POE324          1.0
# 1351             Sévines     Bâtiment         VJO012          1.0
# 1352             Sévines     Bâtiment         MPO012          1.0
# 1354             Sévines     Propreté         POL009          1.0
# 1357             Sévines      ContReg         CRO101          1.0
# 1361             Sévines    Eclairage         ECPO05          1.0
# 1362             Sévines    Eclairage         ECPO18          1.0
# 1363             Sévines    Eclairage         ECPO56          1.0
# 1364             Sévines    Eclairage         ECPO57          1.0
# 1365             Sévines    Eclairage         ECPO58          1.0
# 1366             Sévines          AEV         AEFO14          1.0
# 1367             Sévines          AEV         AEPO14          1.0
# 1369             Sévines     Automate         AUPR09          1.0
# 1370             Sévines     Automate         AUPR10          1.0
# 1373             Sévines      PAU/TSE       RAU-PO05          1.0
# 1374             Sévines      PAU/TSE       TSE-PO05          1.0
# 1397             Sévines    Détection         DEP010          1.0
# 1397             Sévines    Détection         DEP010          1.0
# 1415             Sévines  Ventilation         VPO203          1.0
# 1415             Sévines  Ventilation         VPO203          1.0
# 1421             Sévines        Vidéo      VI MP 133          1.0
# 1421             Sévines        Vidéo      VI MP 133          1.0
# 1422             Sévines        Vidéo      VI MP 333          1.0
# 1422             Sévines        Vidéo      VI MP 333          1.0
# 1423             Sévines        Vidéo      VI MP 416          1.0
# 1423             Sévines        Vidéo      VI MP 416          1.0
# 1424             Sévines      Pompage         INP309          1.0
# 1424             Sévines      Pompage         INP309          1.0
# 1440             Bobigny     Bâtiment         VNN001          1.0
# 1441             Bobigny     Bâtiment         VNN002          1.0
# 1442             Bobigny     Bâtiment         MPN001          1.0
# 1443             Bobigny     Bâtiment         MPN002          1.0
# 1444             Bobigny     Propreté         POL012          1.0
# 1447             Bobigny      ContReg         CRN109          1.0
# 1448             Bobigny      ContReg         CRN110          1.0
# 1449             Bobigny      ContReg         CRN111          1.0
# 1450             Bobigny      ContReg         CRN112          1.0
# 1451             Bobigny      ContReg         CRN113          1.0
# 1455             Bobigny    Eclairage         ECPN01          1.0
# 1456             Bobigny    Eclairage         ECPN10          1.0
# 1457             Bobigny    Eclairage         ECPN50          1.0
# 1458             Bobigny    Eclairage         ECPN51          1.0
# 1459             Bobigny    Eclairage         ECPN52          1.0
# 1460             Bobigny          AEV         AEFN10          1.0
# 1461             Bobigny          AEV         AEPN20          1.0
# 1463             Bobigny     Automate         AUPR35          1.0
# 1464             Bobigny     Automate         AUPR36          1.0
# 1467             Bobigny      PAU/TSE       RAU-PN03          1.0
# 1468             Bobigny      PAU/TSE       TSE-PN03          1.0
# 1491             Bobigny    Détection         DEP013          0.5
# 1491             Bobigny    Détection         DEP013          0.5
# 1509             Bobigny  Ventilation         VPN201          0.5
# 1509             Bobigny  Ventilation         VPN201          0.5
# 1515             Bobigny        Vidéo      VI MP 109          1.0
# 1515             Bobigny        Vidéo      VI MP 109          1.0
# 1516             Bobigny        Vidéo      VI MP 309          1.0
# 1516             Bobigny        Vidéo      VI MP 309          1.0
# 1517             Bobigny        Vidéo      VI MP 404          1.0
# 1517             Bobigny        Vidéo      VI MP 404          1.0
# 1518             Bobigny      Pompage         INP105          1.0
# 1518             Bobigny      Pompage         INP105          1.0
# 1523             Bobigny      Pompage         POE701          1.0
# 1523             Bobigny      Pompage         POE701          1.0
# 1540        La Courneuve     Propreté         POL013          1.0
# 1543        La Courneuve      ContReg         CRN106          1.0
# 1547        La Courneuve    Eclairage         ECPN04          1.0
# 1548        La Courneuve    Eclairage         ECPN16          1.0
# 1549        La Courneuve    Eclairage         ECPN61          1.0
# 1550        La Courneuve    Eclairage         ECPN62          1.0
# 1551        La Courneuve    Eclairage         ECPN63          1.0
# 1552        La Courneuve          AEV         AEFN12          1.0
# 1553        La Courneuve          AEV         AEPN22          1.0
# 1555        La Courneuve     Automate         AUPR41          1.0
# 1555        La Courneuve     Automate         AUPR41          1.0
# 1556        La Courneuve     Automate         AUPR42          1.0
# 1559        La Courneuve      PAU/TSE       RAU-PN04          1.0
# 1560        La Courneuve      PAU/TSE       TSE-PN04          1.0
# 1604        La Courneuve        Vidéo      VI MP 113          1.0
# 1604        La Courneuve        Vidéo      VI MP 113          1.0
# 1605        La Courneuve        Vidéo      VI MP 313          1.0
# 1605        La Courneuve        Vidéo      VI MP 313          1.0
# 1606        La Courneuve        Vidéo      VI MP 406          1.0
# 1606        La Courneuve        Vidéo      VI MP 406          1.0
# 1607        La Courneuve      Pompage         INP102          1.0
# 1607        La Courneuve      Pompage         INP102          1.0
# 1625               Landy     Bâtiment         VNN003          1.0
# 1626               Landy     Bâtiment         VNN004          1.0
# 1627               Landy     Bâtiment         MPN003          1.0
# 1628               Landy     Bâtiment         MPN004          1.0
# 1629               Landy     Propreté         POL011          1.0
# 1632               Landy      ContReg         CRN101          1.0
# 1633               Landy      ContReg         CRN102          1.0
# 1634               Landy      ContReg         CRN103          1.0
# 1635               Landy      ContReg         CRN104          1.0
# 1636               Landy      ContReg         CRN105          1.0
# 1640               Landy    Eclairage         ECPN05          1.0
# 1641               Landy    Eclairage         ECPN18          1.0
# 1642               Landy    Eclairage         ECPN64          1.0
# 1643               Landy    Eclairage         ECPN65          1.0
# 1644               Landy    Eclairage         ECPN66          1.0
# 1645               Landy          AEV         AEFN13          1.0
# 1646               Landy          AEV         AEPN23          1.0
# 1648               Landy     Automate         AUPR39          1.0
# 1649               Landy     Automate         AUPR40          1.0
# 1652               Landy      PAU/TSE       RAU-PN01          1.0
# 1653               Landy      PAU/TSE       TSE-PN01          1.0
# 1676               Landy    Détection         DEP012          1.0
# 1676               Landy    Détection         DEP012          1.0
# 1694               Landy  Ventilation         VPN200          1.0
# 1694               Landy  Ventilation         VPN200          1.0
# 1700               Landy        Vidéo      VI MP 107          1.0
# 1700               Landy        Vidéo      VI MP 107          1.0
# 1701               Landy        Vidéo      VI MP 307          1.0
# 1701               Landy        Vidéo      VI MP 307          1.0
# 1702               Landy        Vidéo      VI MP 403          1.0
# 1702               Landy        Vidéo      VI MP 403          1.0
# 1703               Landy      Pompage         INP101          1.0
# 1703               Landy      Pompage         INP101          1.0
# 1705               Landy      Pompage         POP101          1.0
# 1705               Landy      Pompage         POP101          1.0
# 1730        Lumen-Norton      ContReg         CRN107          1.0
# 1731        Lumen-Norton      ContReg         CRN108          1.0
# 1735        Lumen-Norton    Eclairage         ECPN02          1.0
# 1736        Lumen-Norton    Eclairage         ECPN12          1.0
# 1737        Lumen-Norton    Eclairage         ECPN53          1.0
# 1738        Lumen-Norton    Eclairage         ECPN55          1.0
# 1739        Lumen-Norton    Eclairage         ECPN57          1.0
# 1740        Lumen-Norton    Eclairage         ECPN59          1.0
# 1741        Lumen-Norton          AEV         AEFN11          1.0
# 1742        Lumen-Norton          AEV         AEPN21          1.0
# 1744        Lumen-Norton     Automate         AUPR37          1.0
# 1745        Lumen-Norton     Automate         AUPR38          1.0
# 1796        Lumen-Norton        Vidéo      VI MP 111          1.0
# 1796        Lumen-Norton        Vidéo      VI MP 111          1.0
# 1797        Lumen-Norton        Vidéo      VI MP 311          1.0
# 1798        Lumen-Norton        Vidéo      VI MP 405          1.0
# 1798        Lumen-Norton        Vidéo      VI MP 405          1.0
# 1799        Lumen-Norton      Pompage         INP103          1.0
# 1799        Lumen-Norton      Pompage         INP103          1.0
# 1816             Taverny     Bâtiment         VNN005          1.0
# 1817             Taverny     Bâtiment         MPN005          1.0
# 1818             Taverny     Propreté         POL010          1.0
# 1821             Taverny      ContReg         CRN114          1.0
# 1825             Taverny    Eclairage         ECPN06          1.0
# 1826             Taverny    Eclairage         ECPN20          1.0
# 1827             Taverny    Eclairage         ECPN67          1.0
# 1828             Taverny    Eclairage         ECPN68          1.0
# 1829             Taverny    Eclairage         ECPN69          1.0
# 1830             Taverny          AEV         AEFN14          1.0
# 1831             Taverny          AEV         AEPN24          1.0
# 1834             Taverny     Automate         AUPR44          1.0
# 1837             Taverny      PAU/TSE       RAU-PN02          1.0
# 1838             Taverny      PAU/TSE       TSE-PN02          1.0
# 1861             Taverny    Détection         DEP011          1.0
# 1861             Taverny    Détection         DEP011          1.0
# 1879             Taverny  Ventilation         VPN202          1.0
# 1879             Taverny  Ventilation         VPN202          1.0
# 1885             Taverny        Vidéo      VI MP 115          1.0
# 1885             Taverny        Vidéo      VI MP 115          1.0
# 1886             Taverny        Vidéo      VI MP 315          1.0
# 1886             Taverny        Vidéo      VI MP 315          1.0
# 1887             Taverny        Vidéo      VI MP 407          1.0
# 1887             Taverny        Vidéo      VI MP 407          1.0
# 1888             Taverny      Pompage         INP104          1.0
# 1888             Taverny      Pompage         INP104          1.0
# 1904              Antony     Bâtiment         VJS003          0.5
# 1905              Antony     Bâtiment         VJS004          0.5
# 1906              Antony     Bâtiment         VNS003          0.5
# 1907              Antony     Bâtiment         VNS004          0.5
# 1908              Antony     Bâtiment         MPS003          0.5
# 1909              Antony     Bâtiment         MPS004          0.5
# 1910              Antony     Propreté         POL017          0.5
# 1913              Antony      ContReg         CRS101          1.0
# 1914              Antony      ContReg         CRS102          1.0
# 1915              Antony      ContReg         CRS103          1.0
# 1916              Antony      ContReg         CRS104          1.0
# 1920              Antony    Eclairage         ECPS02          1.0
# 1921              Antony    Eclairage         ECPS12          1.0
# 1922              Antony    Eclairage         ECPS53          1.0
# 1923              Antony    Eclairage         ECPS54          1.0
# 1924              Antony    Eclairage         ECPS55          1.0
# 1925              Antony          AEV         AEFS11          1.0
# 1926              Antony          AEV         AEPS21          1.0
# 1928              Antony     Automate         AUPR21          0.5
# 1929              Antony     Automate         AUPR22          0.5
# 1932              Antony      PAU/TSE       RAU-PS01          0.5
# 1933              Antony      PAU/TSE       TSE-PS01          0.5
# 1956              Antony    Détection         DEP018          0.5
# 1956              Antony    Détection         DEP018          0.5
# 1974              Antony  Ventilation         VPS200          1.0
# 1980              Antony        Vidéo      VI MP 137          1.0
# 1980              Antony        Vidéo      VI MP 137          1.0
# 1981              Antony        Vidéo      VI MP 337          1.0
# 1981              Antony        Vidéo      VI MP 337          1.0
# 1982              Antony        Vidéo      VI MP 418          1.0
# 1982              Antony        Vidéo      VI MP 418          1.0
# 1983              Antony      Pompage         INP401          1.0
# 1984              Antony      Pompage         POE401          1.0
# 1984              Antony      Pompage         POE401          1.0
# 2009             Fresnes      ContReg            NaN          0.0
# 2013             Fresnes    Eclairage         ECPS04          1.0
# 2014             Fresnes    Eclairage         ECPS16          1.0
# 2015             Fresnes    Eclairage         ECPS59          1.0
# 2016             Fresnes    Eclairage         ECPS60          1.0
# 2017             Fresnes    Eclairage         ECPS61          1.0
# 2018             Fresnes          AEV         AEFS13          1.0
# 2019             Fresnes          AEV         AEPS23          1.0
# 2067             Fresnes  Ventilation         VPS201          1.0
# 2073             Fresnes        Vidéo      VI MP 139          1.0
# 2073             Fresnes        Vidéo      VI MP 139          1.0
# 2074             Fresnes        Vidéo      VI MP 339          1.0
# ...
# 1491       6840.75   27363.000             0.00         52120.00
# 1491       6840.75   27363.000         34715.16             0.00
# 1509      39474.35   19737.175             0.00         38076.92
# 1509      39474.35   19737.175         21117.71             0.00
# 1515       4055.90    4055.900             0.00             0.00
# 1515       4055.90    4055.900          7174.42             0.00
# 1516       3040.80    6081.600             0.00          6081.60
# 1516       3040.80    6081.600         16129.23             0.00
# 1517        252.80     252.800             0.00           505.60
# 1517        252.80     252.800          1376.46             0.00
# 1518       2910.00    2910.000             0.00             0.00
# 1518       2910.00    2910.000          2734.93             0.00
# 1523        147.54     590.160             0.00             0.00
# 1523        147.54     590.160        141169.15             0.00
# 1540       6922.20   27688.800         11632.00         12143.80
# 1543        324.30     324.300             0.00             0.00
# 1547        162.90     651.600           893.40           913.92
# 1548       3459.49   13837.960          6469.94             0.00
# 1549       9242.47    7393.976             0.00             0.00
# 1550       2378.58    1902.864             0.00             0.00
# 1551       5436.75    4349.400             0.00             0.00
# 1552        397.62    1590.480          1453.80           768.34
# 1553        810.41    3241.640          1481.56          1515.64
# 1555        309.50     309.500             0.00           296.74
# 1555        309.50     309.500             0.00           273.20
# 1556        334.51     334.510             0.00           320.72
# 1559        337.92    1351.680             0.00           323.37
# 1560        134.95     539.800             0.00           129.14
# 1604       1710.20    1710.200             0.00             0.00
# 1604       1710.20    1710.200          2110.13             0.00
# 1605       1624.70    3249.400             0.00          3249.40
# 1605       1624.70    3249.400          4743.90             0.00
# 1606         44.60      44.600             0.00            89.20
# 1606         44.60      44.600            80.97             0.00
# 1607        613.00     613.000             0.00             0.00
# 1607        613.00     613.000           575.94             0.00
# 1625       1958.00   11748.000             0.00             0.00
# 1626       1958.00   11748.000             0.00             0.00
# 1627       2111.00    2111.000             0.00             0.00
# 1628       2111.00    2111.000             0.00             0.00
# 1629      10734.42   42937.680         36076.00         37663.36
# 1632        324.30     324.300             0.00             0.00
# 1633        324.30     324.300             0.00             0.00
# 1634        324.30     324.300             0.00             0.00
# 1635        216.20     216.200             0.00             0.00
# 1636        216.20     216.200             0.00             0.00
# 1640        814.49    3257.960          2978.00          4569.72
# 1641       8993.74   35974.960             0.00             0.00
# 1642      30785.54   24628.432             0.00             0.00
# 1643      15341.82   12273.456             0.00             0.00
# 1644       5062.97    4050.376             0.00             0.00
# 1645       1024.39    4097.560          3745.48          3895.30
# 1646       3491.55   13966.200          6383.08          6529.90
# 1648        358.59     358.590             0.00           343.81
# 1649       2119.17    2119.170             0.00          2031.80
# 1652       1400.52    5602.080             0.00          1340.21
# 1653        899.67    3598.680             0.00           860.93
# 1676       5363.40   42907.200             0.00         40864.00
# 1676       5363.40   42907.200         24123.60             0.00
# 1694      31888.73   31888.730             0.00         30759.84
# 1694      31888.73   31888.730         18287.64             0.00
# 1700       3200.80    3200.800             0.00             0.00
# 1700       3200.80    3200.800          4747.78             0.00
# 1701       3040.80    6081.600             0.00          6081.60
# 1701       3040.80    6081.600         10673.76             0.00
# 1702        297.40     297.400             0.00           594.80
# 1702        297.40     297.400           539.78             0.00
# 1703       3062.00    3062.000             0.00             0.00
# 1703       3062.00    3062.000          2878.66             0.00
# 1705        463.39    1390.170             0.00             0.00
# 1705        463.39    1390.170           922.32             0.00
# 1730        432.40     432.400             0.00             0.00
# 1731        324.30     324.300             0.00             0.00
# 1735        162.90     651.600           893.40           913.92
# 1736       6271.51   25086.040             0.00             0.00
# 1737       6931.86    5545.488         25927.92             0.00
# 1738       3465.93    2772.744             0.00             0.00
# 1739       3380.98    2704.784             0.00             0.00
# 1740       1189.29     951.432             0.00             0.00
# 1741        397.62    1590.480          1453.80          1511.96
# 1742        810.41    3241.640          1481.56          1515.64
# 1744        524.99     524.990             0.00           503.35
# 1745        718.61     718.610             0.00           688.98
# 1796       3200.80    3200.800             0.00             0.00
# 1796       3200.80    3200.800         14348.84             0.00
# 1797       1624.70    3249.400             0.00          3249.40
# 1798         59.50      59.500             0.00           119.00
# 1798         59.50      59.500           107.95             0.00
# 1799       1516.00    1516.000             0.00             0.00
# 1799       1516.00    1516.000          1424.85             0.00
# 1816       1306.00   15672.000             0.00             0.00
# 1817       1407.00    2814.000             0.00             0.00
# 1818       4786.98   19147.920          8044.00          8397.94
# 1821        432.40     432.400             0.00             0.00
# 1825        162.90     651.600           893.40           913.92
# 1826       5444.45   21777.800             0.00             0.00
# 1827      10805.52    8644.416             0.00             0.00
# 1828       5402.78    4322.224         10104.28             0.00
# 1829       6863.89    5491.112             0.00             0.00
# 1830        428.81    1715.240          1567.88          1630.60
# 1831        950.54    3802.160          1737.72          1777.68
# 1834        436.40     436.400             0.00           418.41
# 1837        466.84    1867.360             0.00           446.74
# 1838        179.94     719.760             0.00           172.19
# 1861       2859.15   22873.200             0.00         16338.00
# 1861       2859.15   22873.200          5631.80             0.00
# 1879       5181.02    5181.020             0.00          4997.60
# 1879       5181.02    5181.020          4520.36             0.00
# 1885       1710.20    1710.200             0.00             0.00
# 1885       1710.20    1710.200          1160.57             0.00
# 1886        812.40    1624.800             0.00          1624.80
# 1886        812.40    1624.800          2609.13             0.00
# 1887         59.50      59.500             0.00           119.00
# 1887         59.50      59.500           107.95             0.00
# 1888       1164.00    1164.000             0.00             0.00
# 1888       1164.00    1164.000          1093.97             0.00
# 1904        507.00    3042.000             0.00             0.00
# 1905        507.00    3042.000             0.00             0.00
# 1906       1306.00    7836.000             0.00             0.00
# 1907       1306.00    7836.000             0.00             0.00
# 1908       1407.00    1407.000             0.00             0.00
# 1909       1407.00    1407.000             0.00             0.00
# 1910      13633.74   27267.480         23918.04             0.00
# 1913       1297.20    1297.200             0.00             0.00
# 1914        432.40     432.400             0.00             0.00
# 1915        864.80     864.800             0.00             0.00
# 1916        864.80     864.800             0.00             0.00
# 1920        407.24    1628.960             0.00          1573.88
# 1921       1824.27    7297.080             0.00             0.00
# 1922       5470.71    4376.568             0.00             0.00
# 1923       3109.14    2487.312             0.00             0.00
# 1924       4519.29    3615.432             0.00             0.00
# 1925        620.95    2483.800             0.00             0.00
# 1926       1675.71    6702.840          3133.92          6476.16
# 1928        309.50     154.750             0.00           296.74
# 1929       1593.58     796.790             0.00          1527.88
# 1932       1689.62    3379.240             0.00          1689.62
# 1933        449.84     899.680             0.00           430.47
# 1956       5597.55   22390.200             0.00         15993.00
# 1956       5597.55   22390.200         10232.36             0.00
# 1974       5513.22    5513.220             0.00          5318.04
# 1980       1539.20    1539.200             0.00          1539.20
# 1980       1539.20    1539.200          2004.62             0.00
# 1981       1624.70    3249.400             0.00          1624.70
# 1981       1624.70    3249.400          1502.24             0.00
# 1982        133.80     133.800             0.00           133.80
# 1982        133.80     133.800           242.91             0.00
# 1983       1441.00    1441.000             0.00          1441.00
# 1984       5814.24   17442.720             0.00          6863.00
# 1984       5814.24   17442.720          5786.26             0.00
# 2009           NaN         NaN             0.00             0.00
# 2013        240.68     962.720             0.00           930.16
# 2014       5279.03   21116.120             0.00             0.00
# 2015      16514.09   13211.272             0.00             0.00
# 2016       3126.13    2500.904             0.00             0.00
# 2017      11790.94    9432.752             0.00             0.00
# 2018        385.57    1542.280             0.00             0.00
# 2019        732.16    2928.640          1369.28          2829.60
# 2067       7613.49    7613.490             0.00          7343.96
# 2073       2880.80    2880.800             0.00          2880.80
# 2073       2880.80    2880.800          2954.17             0.00
# 2074       1624.70    3249.400             0.00          1624.70
# 2074       1624.70    3249.400          2213.82             0.00
# 2075         29.70      29.700             0.00            29.70
# 2075         29.70      29.700            53.98             0.00
# 2076       1441.00    1441.000             0.00          1441.00
# 2077       1252.00    3756.000             0.00             0.00
# 2081       1934.62    1934.620             0.00          2265.00
# 2091        507.00    3042.000             0.00             0.00
# 2092        507.00    3042.000             0.00             0.00
# 2093       1306.00    7836.000             0.00             0.00
# 2094       1306.00    7836.000             0.00             0.00
# 2095       1407.00    1407.000             0.00             0.00
# 2096       1407.00    1407.000             0.00             0.00
# 2097       8670.61   34682.440         14570.00         15211.08
# 2100        864.80     864.800             0.00             0.00
# 2101        864.80     864.800             0.00             0.00
# 2105        407.24    1628.960          2267.74          2335.50
# 2106       5449.18   21796.720          9961.92             0.00
# 2107       7696.40    6157.120             0.00             0.00
# 2108       5470.71    4376.568             0.00             0.00
# 2109      23921.68   19137.344             0.00             0.00
# 2110        714.56    2858.240             0.00             0.00
# 2111       2096.07    8384.280         11672.10         12020.80
# 2113        334.05     167.025           320.28           320.28
# 2114       1805.52     902.760          1731.08          1731.08
# 2117       2208.71    4417.420          2113.60          4322.31
# 2118        584.79    1169.580           559.61          1144.40
# 2141       6303.15   50425.200             0.00         18009.00
# 2141       6303.15   50425.200          3120.80             0.00
# 2159       9212.68    9212.680             0.00         17773.08
# 2159       9212.68    9212.680         10826.52             0.00
# 2165       3200.80    1600.400             0.00          3200.80
# 2165       3200.80    1600.400          8862.51             0.00
# 2166       3200.80    1600.400             0.00          3200.80
# 2166       3200.80    1600.400          8862.51             0.00
# 2167       1624.70    1624.700             0.00             0.00
# 2168       1624.70    1624.700             0.00             0.00
# 2169        193.30      96.650             0.00           193.30
# 2169        193.30      96.650           809.67             0.00
# 2170       2402.00    2402.000             0.00          2402.00
# 2171        231.70     695.100             0.00             0.00
# 2172        231.70     695.100             0.00             0.00
# 2193       4786.98   19147.920          8044.00          8397.94
# 2196        864.80     864.800             0.00             0.00
# 2200        244.34     977.360          1360.66          1401.30
# 2201       1228.78    4915.120          2246.40             0.00
# 2202       1919.86    1535.888             0.00             0.00
# 2203       1648.01    1318.408             0.00             0.00
# 2204       2361.59    1889.272             0.00             0.00
# 2205        383.80    1535.200             0.00             0.00
# 2206        771.30    3085.200          4295.00          4423.32
# 2236       2880.15   11520.600             0.00          8229.00
# 2236       2880.15   11520.600          3812.50             0.00
# 2264        961.00     961.000             0.00           961.00
# 2277        507.00    3042.000             0.00             0.00
# 2278       1306.00    7836.000             0.00             0.00
# 2279       1407.00    1407.000             0.00             0.00
# 2280       4786.98   19147.920          4022.00          4198.97
# 2283        216.20     216.200             0.00             0.00
# 2287        240.68     962.720          1340.24          1380.28
# 2288       3686.35   14745.400          6739.20             0.00
# 2289       3177.08    2541.664             0.00             0.00
# 2290       2106.74    1685.392             0.00             0.00
# 2291      16344.19   13075.352             0.00             0.00
# 2292        385.57    1542.280             0.00             0.00
# 2293        802.22    3208.880          4467.22          4600.68
# 2295        284.95     284.950           273.20           273.20
# 2299        700.25    2801.000           670.10          1370.35
# 2300         89.96     359.840            86.09           176.05
# 2323       2903.25   11613.000             0.00          8295.00
# 2345       1710.20    1710.200             0.00          3420.40
# 2345       1710.20    1710.200          5697.33             0.00
# 2346       1624.70    3249.400             0.00             0.00
# 2347         29.70      29.700             0.00            29.70
# 2347         29.70      29.700           161.94             0.00
# 2348       1922.00    1922.000             0.00          1922.00
# 2348       1922.00    1922.000          1224.98             0.00
