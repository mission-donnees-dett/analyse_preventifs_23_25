# %%
# Import des bibliothèques 

import openpyxl
import pandas as pd
import re
from openpyxl.utils.cell import column_index_from_string
import requests
import io
import openpyxl

# %%
# Configuration des paramètres 

FILE_URL = 'https://raw.githubusercontent.com/mission-donnees-dett/analyse_preventifs_23_25/main/Tunnels_Cout%20pre%CC%81ventif_13.06.2025%20(5).xlsx'
TARGET_MARCHES = {"Bâtiment", "Propreté", "ContReg", "Eclairage", "AEV", "Automate", "PAU/TSE", "Onduleur", "Détection", "Ventilation", "Vidéo", "Pompage"}
TUNNEL_SHEETS = {'Boissy', 'Champigny', 'Guy Môquet', 'Moulin', 'Nogent',
    'Ambroise Paré', 'Belle-Rive', 'Chennevières', 'Fontenay', 'La Défense',
    'Nanterre Centre', 'Nanterre échangeur', 'Neuilly', 'Saint-Cloud', 'Sévines',
    'Bobigny', 'La Courneuve', 'Landy', 'Lumen-Norton', 'Taverny',
    'Antony', 'Fresnes', 'Bicêtre', 'Italie', 'Orly'}  # Liste des noms de feuilles tunnels
PREVENTIF_SHEET = 'Préventifs_tunnels'

# %%
# Téléchargement et chargement du classeur Excel depuis GitHub 

response = requests.get(FILE_URL)
if response.status_code != 200:
    raise FileNotFoundError(f"Failed to download file: {FILE_URL}")
wb = openpyxl.load_workbook(io.BytesIO(response.content), data_only=False)
ws_preventif = wb[PREVENTIF_SHEET]

# %%
# Résolution de valeur/formule de cellule (même avec réf. croisée) 

def resolve_cell_value(ws, cell):
    value = cell.value
    if isinstance(value, str) and value.startswith('='):
        match = re.match(r'=([A-Za-z0-9_]+)!([A-Z]+)(\d+)', value)
        if match:
            sheet_name, col, row = match.groups()
            try:
                target_ws = wb[sheet_name]
                target_cell = target_ws[f"{col}{row}"]
                return resolve_cell_value(target_ws, target_cell)
            except Exception as e:
                print(f"    ⚠️ Failed to resolve cross-sheet reference {value}: {e}")
                return None
        else:
            return None
    try:
        return float(value)
    except:
        return None

# %%
# Évaluation simple des formules (type A1+A2+A3)

def evaluate_simple_formula(ws, formula, row_num):
    if not isinstance(formula, str) or not formula.startswith('='):
        try:
            return float(formula)
        except:
            return None

    formula = formula.strip('=').replace(' ', '')
    parts = formula.split('+')
    total = 0
    for ref in parts:
        match = re.match(r'([A-Z]+)(\d+)?', ref)
        if not match:
            return None
        col_letter = match.group(1)
        row_number = int(match.group(2)) if match.group(2) else row_num
        try:
            col_index = column_index_from_string(col_letter)
            cell = ws.cell(row=row_number, column=col_index)
            val = resolve_cell_value(ws, cell)
            if val is None:
                return None
            total += float(val)
        except Exception:
            return None
    return total

# %%
# Analyse du type de formule et extraction des références

def parse_formula(formula):
    range_matches = re.findall(r'Préventifs_tunnels!G(\d+)(?::G(\d+))?', formula)
    refs = []
    for start_str, end_str in range_matches:
        start = int(start_str)
        if end_str:
            end = int(end_str)
            refs.extend(range(start, end + 1))
        else:
            refs.append(start)

    coeff = 0.5 if '/2' in formula else 1

    if '/2' in formula:
        form_typ = 'div_2'
    elif len(refs) == 1 and formula.strip('=') == f"Préventifs_tunnels!G{refs[0]}":
        form_typ = 'direct_reference'
    elif 'SUM' in formula.upper():
        form_typ = f"sum_{len(refs)}"
    elif '+' in formula:
        form_typ = f"sum_{len(refs)}" if len(refs) >= 2 else 'unknown'
    else:
        form_typ = 'unknown'

    return refs, form_typ, coeff

# %%
# Résolution du champ 'Nombre équipé' en cas de formule

def resolve_nb_eq_value(ws, cell, depth=0):
    MAX_DEPTH = 5
    if depth > MAX_DEPTH:
        return 0

    value = cell.value
    if isinstance(value, str) and value.startswith('='):
        matches_cross = re.findall(r"'([^']+)'!([A-Z]+)(\d+)", value)
        if matches_cross:
            total = 0
            for sheet_name, col, row in matches_cross:
                if sheet_name in wb.sheetnames:
                    try:
                        target_ws = wb[sheet_name]
                        target_cell = target_ws[f"{col}{row}"]
                        val = resolve_nb_eq_value(target_ws, target_cell, depth + 1)
                        total += val if val is not None else 0
                    except Exception:
                        continue
            return total

        matches_same = re.findall(r"([A-Z]+)(\d+)", value)
        if matches_same:
            total = 0
            for col, row in matches_same:
                try:
                    target_cell = ws[f"{col}{row}"]
                    val = resolve_nb_eq_value(ws, target_cell, depth + 1)
                    total += val if val is not None else 0
                except Exception:
                    continue
            return total

        try:
            expr = value.lstrip('=').replace(',', '.')
            if re.fullmatch(r'[\d\.\+\-\*\/\(\) ]+', expr):
                return float(eval(expr, {"__builtins__": None}, {}))
        except:
            return 0

    try:
        return float(value) if float(value) != 0 else 0
    except:
        return 0

# %%
# Résolution du champ 'Coût HT' même avec formule ou réf. croisée

def resolve_cout_ht(ws, cell, depth=0):
    MAX_DEPTH = 10
    if depth > MAX_DEPTH:
        return None

    val = cell.value
    if isinstance(val, str) and val.startswith('='):
        match_sheet = re.match(r"='([^']+)'!([A-Z]+)(\d+)", val)
        if match_sheet:
            sheet_name, col, row = match_sheet.groups()
            if sheet_name in wb.sheetnames:
                target_ws = wb[sheet_name]
                target_cell = target_ws[f"{col}{row}"]
                return resolve_cout_ht(target_ws, target_cell, depth + 1)
        match_same = re.match(r"=([A-Z]+)(\d+)", val)
        if match_same:
            col, row = match_same.groups()
            return resolve_cout_ht(ws, ws[f"{col}{row}"], depth + 1)

        cached_value = getattr(cell, 'cached_value', None)
        if cached_value is None:
            cached_value = getattr(cell, '_value', None)

        if cached_value is not None:
            try:
                return float(str(cached_value).replace(',', '.'))
            except:
                return 0
        return 0

    try:
        return float(val)
    except:
        return 0

# %%
# Traitement des lignes d'une feuille tunnel

def process_tunnel_sheet(ws_tunnel):
    print(f"\nProcessing tunnel sheet: {ws_tunnel.title}")

    header_row = ws_tunnel[2]
    headers = {}
    for idx, cell in enumerate(header_row):
        if cell.value:
            clean_header = str(cell.value).strip().replace('\n', ' ')
            headers[clean_header] = idx
    print(f"Headers found: {list(headers.keys())}")

    col_marche = headers.get('Marché')
    col_freq = headers.get('Fréquence totale')
    col_nbeq = headers.get('Nombre équipé')
    col_cht = headers.get('Coût HT')

    if None in (col_marche, col_freq, col_nbeq, col_cht):
        print(f"⚠️ Missing one or more required columns in sheet {ws_tunnel.title}. Skipping.")
        return [], {}

    sheet_results = []
    skipped_reasons = {}

    for row in ws_tunnel.iter_rows(min_row=3):
        marche_raw = row[col_marche].value
        if marche_raw is None:
            continue
        marche = str(marche_raw).strip()
        if marche not in TARGET_MARCHES:
            continue

        raw_freq = row[col_freq].value
        freq = evaluate_simple_formula(ws_tunnel, raw_freq, row[0].row)
        if freq is None:
            skipped_reasons[row[0].row] = "Invalid frequency"
            continue

        nb_eq = resolve_nb_eq_value(ws_tunnel, row[col_nbeq])
        if nb_eq is None:
            skipped_reasons[row[0].row] = "Could not resolve nb_eq"
            continue

        cell_cht = row[col_cht]
        cell_value = cell_cht.value
        cell_type = cell_cht.data_type

        mar_diminutif = marche
        tunnel = ws_tunnel.title

        if cell_type != 'f':
            try:
                cout_ht_resolved = float(cell_value)
            except:
                cout_ht_resolved = 0
            total = freq * nb_eq * cout_ht_resolved
            sheet_results.append({
                'mar_diminutif': mar_diminutif,
                'tunnel': tunnel,
                'ref_prix': None,
                'form_typ': 'direct_value',
                'frq_totale': freq,
                'nb_equipe': nb_eq,
                'coeff': 1,
                'cout_ht': cout_ht_resolved,
                'cout_total': round(total, 2)
            })
            continue

        formula = cell_value
        if 'Préventifs_tunnels!G' not in formula:
            skipped_reasons[row[0].row] = "Formula does not reference Préventifs_tunnels!G"
            continue

        refs, form_typ, coeff = parse_formula(formula)

        for ref_row in refs:
            ref_prix = ws_preventif[f'D{ref_row}'].value
            cout_ht_cell = ws_preventif[f'G{ref_row}']
            cout_ht_resolved = resolve_cout_ht(ws_preventif, cout_ht_cell)
            if cout_ht_resolved is None:
                skipped_reasons[row[0].row] = f"Could not resolve cout_ht for G{ref_row}"
                continue

            total = freq * nb_eq * coeff * cout_ht_resolved
            sheet_results.append({
                'mar_diminutif': mar_diminutif,
                'tunnel': tunnel,
                'ref_prix': ref_prix,
                'form_typ': form_typ,
                'frq_totale': freq,
                'nb_equipe': nb_eq,
                'coeff': coeff,
                'cout_ht': cout_ht_resolved,
                'cout_total': round(total, 2)
            })

    return sheet_results, skipped_reasons

# %%
# Exécution sur toutes les feuilles tunnel

all_results = []
all_skipped = {}

for tunnel_name in TUNNEL_SHEETS:
    if tunnel_name not in wb.sheetnames:
        print(f"⚠️ Sheet '{tunnel_name}' not found, skipping.")
        continue
    ws_tunnel = wb[tunnel_name]
    results, skipped = process_tunnel_sheet(ws_tunnel)
    all_results.extend(results)
    if skipped:
        all_skipped[tunnel_name] = skipped


# Création du DataFrame final

df = pd.DataFrame(all_results)
if not df.empty:
    cols = df.columns.tolist()
    for col_name in ['mar_diminutif', 'tunnel']:
        if col_name in cols:
            cols.insert(0, cols.pop(cols.index(col_name)))
    df = df[cols]

print("\nFinal DataFrame:")
print(df)

# Récapitulatif des lignes ignorées
print("\nSkipped rows summary (only for rows with marchés in target list):")
total_skipped = 0
for tunnel, skipped in all_skipped.items():
    count = len(skipped)
    total_skipped += count
    skips_desc = ', '.join(f"{row} ({reason})" for row, reason in skipped.items())
    print(f" - {tunnel}: {count} rows skipped [{skips_desc}]")
print(f"Total skipped rows: {total_skipped}")
# Out:
# Processing tunnel sheet: Guy Môquet
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Fresnes
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Bobigny
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: La Courneuve
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Orly
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Fontenay
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Belle-Rive
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Italie
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Saint-Cloud
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Chennevières
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Landy
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Moulin
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Nogent
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Antony
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Nanterre Centre
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Sévines
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: La Défense
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Ambroise Paré
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Nanterre échangeur
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Taverny
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Boissy
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Neuilly
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Lumen-Norton
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Bicêtre
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Processing tunnel sheet: Champigny
# Headers found: ['Marché', 'Opération', 'Fréquence annuelle', 'Ajustement fréquence supplémentaire', 'Fréquence totale', 'Nombre équipé', 'Coût HT', 'Coût total HT', 'Commentaire/Question']
#
# Final DataFrame:
#                   tunnel mar_diminutif   ref_prix          form_typ  frq_totale   nb_equipe  coeff      cout_ht  cout_total
# 0             Guy Môquet      Bâtiment     VJE005             sum_2         6.0    0.500000    1.0   1522.00000     4566.00
# 1             Guy Môquet      Bâtiment     VJE006             sum_2         6.0    0.500000    1.0   1522.00000     4566.00
# 2             Guy Môquet      Bâtiment     VNE005             sum_2         6.0    0.500000    1.0   2611.00000     7833.00
# 3             Guy Môquet      Bâtiment     VNE006             sum_2         6.0    0.500000    1.0   2611.00000     7833.00
# 4             Guy Môquet      Bâtiment     MPE005             sum_2         1.0    0.500000    1.0   2815.00000     1407.50
# 5             Guy Môquet      Bâtiment     MPE006             sum_2         1.0    0.500000    1.0   2815.00000     1407.50
# 6             Guy Môquet      Propreté     POL016  direct_reference         2.0    1.000000    1.0  10734.42000    21468.84
# 7             Guy Môquet       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 8             Guy Môquet       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 9             Guy Môquet       ContReg     CRE105             sum_2         1.0    0.500000    1.0    864.80000      432.40
# 10            Guy Môquet       ContReg     CRE106             sum_2         1.0    0.500000    1.0    864.80000      432.40
# 11            Guy Môquet       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 12            Guy Môquet       ContReg     CRC102  direct_reference         1.0    0.000000    1.0    864.80000        0.00
# 13            Guy Môquet       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 14            Guy Môquet     Eclairage     ECPE01  direct_reference         2.0    1.000000    1.0    855.21000     1710.42
# 15            Guy Môquet     Eclairage     ECPE10  direct_reference         2.0    1.000000    1.0  15985.44000    31970.88
# 16            Guy Môquet     Eclairage     ECPE50             sum_3         0.4    1.000000    1.0  28406.97000    11362.79
# 17            Guy Môquet     Eclairage     ECPE54             sum_3         0.4    1.000000    1.0  17737.38000     7094.95
# 18            Guy Môquet     Eclairage     ECPE56             sum_3         0.4    1.000000    1.0  27455.54000    10982.22
# 19            Guy Môquet           AEV     AEFE10  direct_reference         2.0    1.000000    1.0   1005.24000     2010.48
# 20            Guy Môquet           AEV     AEPE20  direct_reference         2.0    1.000000    1.0   3016.89000     6033.78
# 21            Guy Môquet           AEV      AEV08  direct_reference         1.0    6.000000    1.0     61.70000      370.20
# 22            Guy Môquet      Automate     AUPR31  direct_reference         1.0    0.500000    1.0    397.10535      198.55
# 23            Guy Môquet      Automate     AUPR32  direct_reference         1.0    0.500000    1.0   1450.62633      725.31
# 24            Guy Môquet      Automate     AUPR47  direct_reference         1.0    1.000000    1.0    202.47130      202.47
# 25            Guy Môquet      Automate     AUPR48  direct_reference         1.0    0.000000    1.0     91.39855        0.00
# 26            Guy Môquet       PAU/TSE   RAU-PE04  direct_reference         4.0    0.500000    1.0   1552.88000     3105.76
# 27            Guy Môquet       PAU/TSE   TSE-PE04  direct_reference         4.0    0.500000    1.0    944.66000     1889.32
# 28            Guy Môquet      Onduleur     ONP001  direct_reference         1.0    0.000000    1.0    304.01000        0.00
# 29            Guy Môquet      Onduleur     ONP002  direct_reference         1.0    0.000000    1.0    337.95000        0.00
# 30            Guy Môquet      Onduleur     ONP003  direct_reference         1.0    1.000000    1.0    371.88000      371.88
# 31            Guy Môquet      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 32            Guy Môquet      Onduleur     ONP005  direct_reference         0.5    1.000000    1.0    414.30000      207.15
# 33            Guy Môquet     Détection     DEP016  direct_reference         4.0    1.000000    1.0   6209.70000    24838.80
# 34            Guy Môquet     Détection     DEP027  direct_reference         1.0    2.000000    1.0     24.15000       48.30
# 35            Guy Môquet     Détection     DEP100  direct_reference         1.0    1.000000    1.0    347.55000      347.55
# 36            Guy Môquet     Détection     DEP200  direct_reference         1.0   18.000000    1.0     33.60000      604.80
# 37            Guy Môquet     Détection     DEP201  direct_reference         1.0    0.000000    1.0     21.00000        0.00
# 38            Guy Môquet     Détection     DEP202  direct_reference         1.0    0.000000    1.0     36.75000        0.00
# 39            Guy Môquet     Détection     DEP203  direct_reference         1.0    0.000000    1.0     15.75000        0.00
# 40            Guy Môquet     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 41            Guy Môquet     Détection     DEP205  direct_reference         1.0    0.000000    1.0     26.25000        0.00
# 42            Guy Môquet     Détection     DEP206  direct_reference         1.0    2.000000    1.0     15.75000       31.50
# 43            Guy Môquet   Ventilation     VPE202  direct_reference         1.0    1.000000    1.0  10365.03000    10365.03
# 44            Guy Môquet   Ventilation     VPT300  direct_reference         1.0    4.000000    1.0     78.85000      315.40
# 45            Guy Môquet   Ventilation     VPT301  direct_reference         1.0    0.000000    1.0    128.27000        0.00
# 46            Guy Môquet   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 47            Guy Môquet   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 48            Guy Môquet   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 49            Guy Môquet         Vidéo  VI MP 102             sum_2         1.0    0.500000    1.0   3341.64000     1670.82
# 50            Guy Môquet         Vidéo  VI MP 103             sum_2         1.0    0.500000    1.0   4234.36000     2117.18
# 51            Guy Môquet         Vidéo  VI MP 302             sum_2         2.0    0.500000    1.0   3174.60000     3174.60
# 52            Guy Môquet         Vidéo  VI MP 303             sum_2         2.0    0.500000    1.0   3174.60000     3174.60
# 53            Guy Môquet         Vidéo  VI MP 400  direct_reference         1.0    0.500000    1.0    201.81000      100.91
# 54            Guy Môquet       Pompage     INP201  direct_reference         1.0    1.000000    1.0   2590.00000     2590.00
# 55            Guy Môquet       Pompage       None      direct_value         3.0    0.500000    1.0      0.00000        0.00
# 56            Guy Môquet       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 57            Guy Môquet       Pompage       None      direct_value         1.0    0.000000    1.0      0.00000        0.00
# 58            Guy Môquet       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 59            Guy Môquet       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 60            Guy Môquet       Pompage     INP700  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 61            Guy Môquet       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 62            Guy Môquet       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 63            Guy Môquet       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
# 64               Fresnes      Bâtiment     VJS003             div_2         6.0    2.000000    0.5    507.00000     3042.00
# 65               Fresnes      Bâtiment     VJS004             div_2         6.0    2.000000    0.5    507.00000     3042.00
# 66               Fresnes      Bâtiment     VNS003             div_2         6.0    2.000000    0.5   1306.00000     7836.00
# 67               Fresnes      Bâtiment     VNS004             div_2         6.0    2.000000    0.5   1306.00000     7836.00
# 68               Fresnes      Bâtiment     MPS003             div_2         1.0    2.000000    0.5   1407.00000     1407.00
# 69               Fresnes      Bâtiment     MPS004             div_2         1.0    2.000000    0.5   1407.00000     1407.00
# 70               Fresnes      Propreté     POL017             div_2         2.0    2.000000    0.5  13633.74000    27267.48
# 71               Fresnes       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 72               Fresnes       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 73               Fresnes       ContReg     CRS105             sum_1         1.0    1.000000    1.0    432.40000      432.40
# 74               Fresnes       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 75               Fresnes       ContReg     CRC102  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 76               Fresnes       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 77               Fresnes     Eclairage     ECPS04  direct_reference         2.0    2.000000    1.0    240.68000      962.72
# 78               Fresnes     Eclairage     ECPS16  direct_reference         2.0    2.000000    1.0   5279.03000    21116.12
# 79               Fresnes     Eclairage     ECPS59             sum_3         0.4    2.000000    1.0  16514.09000    13211.27
# 80               Fresnes     Eclairage     ECPS60             sum_3         0.4    2.000000    1.0   3126.13000     2500.90
# 81               Fresnes     Eclairage     ECPS61             sum_3         0.4    2.000000    1.0  11790.94000     9432.75
# 82               Fresnes           AEV     AEFS13  direct_reference         2.0    2.000000    1.0    385.57000     1542.28
# 83               Fresnes           AEV     AEPS23  direct_reference         2.0    2.000000    1.0    732.16000     2928.64
# 84               Fresnes           AEV      AEV08  direct_reference         1.0    9.000000    1.0     61.70000      555.30
# 85               Fresnes      Automate     AUPR21             div_2         1.0    1.000000    0.5    320.77594      160.39
# 86               Fresnes      Automate     AUPR22             div_2         1.0    1.000000    0.5   1651.63828      825.82
# 87               Fresnes      Automate     AUPR47  direct_reference         1.0    2.000000    1.0    202.47130      404.94
# 88               Fresnes      Automate     AUPR48  direct_reference         1.0    7.000000    1.0     91.39855      639.79
# 89               Fresnes       PAU/TSE   RAU-PS01             div_2         4.0    1.000000    0.5   1689.62000     3379.24
# 90               Fresnes       PAU/TSE   TSE-PS01             div_2         4.0    1.000000    0.5    449.84000      899.68
# 91               Fresnes      Onduleur     ONP001  direct_reference         1.0    0.000000    1.0    304.01000        0.00
# 92               Fresnes      Onduleur     ONP002  direct_reference         1.0    1.000000    1.0    337.95000      337.95
# 93               Fresnes      Onduleur     ONP003  direct_reference         1.0    0.000000    1.0    371.88000        0.00
# 94               Fresnes      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 95               Fresnes      Onduleur     ONP005  direct_reference         0.5    0.000000    1.0    414.30000        0.00
# 96               Fresnes     Détection     DEP018             div_2         4.0    2.000000    0.5   5597.55000    22390.20
# 97               Fresnes     Détection     DEP027  direct_reference         1.0    4.000000    1.0     24.15000       96.60
# 98               Fresnes     Détection     DEP100  direct_reference         1.0    1.000000    1.0    347.55000      347.55
# 99               Fresnes     Détection     DEP200  direct_reference         1.0   26.000000    1.0     33.60000      873.60
# 100              Fresnes     Détection     DEP201  direct_reference         1.0    0.000000    1.0     21.00000        0.00
# 101              Fresnes     Détection     DEP202  direct_reference         1.0    0.000000    1.0     36.75000        0.00
# 102              Fresnes     Détection     DEP203  direct_reference         1.0    0.000000    1.0     15.75000        0.00
# 103              Fresnes     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 104              Fresnes     Détection     DEP205  direct_reference         1.0    5.000000    1.0     26.25000      131.25
# 105              Fresnes     Détection     DEP206  direct_reference         1.0    6.000000    1.0     15.75000       94.50
# 106              Fresnes   Ventilation     VPS201  direct_reference         1.0    1.000000    1.0   7613.49000     7613.49
# 107              Fresnes   Ventilation     VPT300  direct_reference         1.0    2.000000    1.0     78.85000      157.70
# 108              Fresnes   Ventilation     VPT301  direct_reference         1.0   29.000000    1.0    128.27000     3719.83
# 109              Fresnes   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 110              Fresnes   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 111              Fresnes   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 112              Fresnes         Vidéo  VI MP 138             sum_2         1.0    1.000000    1.0   1606.92000     1606.92
# 113              Fresnes         Vidéo  VI MP 139             sum_2         1.0    1.000000    1.0   3007.56000     3007.56
# 114              Fresnes         Vidéo  VI MP 338             sum_2         2.0    1.000000    1.0   1272.11000     2544.22
# 115              Fresnes         Vidéo  VI MP 339             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 116              Fresnes         Vidéo  VI MP 419  direct_reference         1.0    1.000000    1.0     31.01000       31.01
# 117              Fresnes       Pompage     INP402  direct_reference         1.0    1.000000    1.0   1441.00000     1441.00
# 118              Fresnes       Pompage     POP402  direct_reference         3.0    1.000000    1.0    858.61000     2575.83
# 119              Fresnes       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 120              Fresnes       Pompage     POE402  direct_reference         1.0    1.000000    1.0   2360.13000     2360.13
# 121              Fresnes       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 122              Fresnes       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 123              Fresnes       Pompage     INP700  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 124              Fresnes       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 125              Fresnes       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 126              Fresnes       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
# 127              Bobigny      Bâtiment     VJN001             sum_2         6.0    0.333333    1.0   2029.00000     4058.00
# 128              Bobigny      Bâtiment     VJN002             sum_2         6.0    0.333333    1.0   2029.00000     4058.00
# 129              Bobigny      Bâtiment     VNN001             sum_2         6.0    0.333333    1.0   3264.00000     6528.00
# 130              Bobigny      Bâtiment     VNN002             sum_2         6.0    0.333333    1.0   3264.00000     6528.00
# 131              Bobigny      Bâtiment     MPN001             sum_2         1.0    0.333333    1.0   3519.00000     1173.00
# 132              Bobigny      Bâtiment     MPN002             sum_2         1.0    0.333333    1.0   3519.00000     1173.00
# 133              Bobigny      Propreté     POL012  direct_reference         2.0    1.000000    1.0  25661.90000    51323.80
# 134              Bobigny       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 135              Bobigny       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 136              Bobigny       ContReg     CRN109             sum_5         1.0    1.000000    1.0    216.20000      216.20
# 137              Bobigny       ContReg     CRN110             sum_5         1.0    1.000000    1.0    432.40000      432.40
# 138              Bobigny       ContReg     CRN111             sum_5         1.0    1.000000    1.0    324.30000      324.30
# 139              Bobigny       ContReg     CRN112             sum_5         1.0    1.000000    1.0    432.40000      432.40
# 140              Bobigny       ContReg     CRN113             sum_5         1.0    1.000000    1.0    216.20000      216.20
# 141              Bobigny       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 142              Bobigny       ContReg     CRC102  direct_reference         1.0    7.000000    1.0    864.80000     6053.60
# 143              Bobigny       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 144              Bobigny     Eclairage     ECPN01  direct_reference         2.0    2.000000    1.0   1018.11000     4072.44
# 145              Bobigny     Eclairage     ECPN10  direct_reference         2.0    2.000000    1.0   8582.56000    34330.24
# 146              Bobigny     Eclairage     ECPN50             sum_3         0.4    2.000000    1.0  18009.21000    14407.37
# 147              Bobigny     Eclairage     ECPN51             sum_3         0.4    2.000000    1.0   9004.60000     7203.68
# 148              Bobigny     Eclairage     ECPN52             sum_3         0.4    2.000000    1.0   3907.66000     3126.13
# 149              Bobigny           AEV     AEFN10  direct_reference         2.0    2.000000    1.0   1263.33000     5053.32
# 150              Bobigny           AEV     AEPN20  direct_reference         2.0    2.000000    1.0   4317.72000    17270.88
# 151              Bobigny           AEV      AEV08  direct_reference         1.0   31.000000    1.0     61.70000     1912.70
# 152              Bobigny      Automate     AUPR35  direct_reference         1.0    1.000000    1.0   1468.62498     1468.62
# 153              Bobigny      Automate     AUPR36  direct_reference         1.0    1.000000    1.0   1655.52988     1655.53
# 154              Bobigny      Automate     AUPR47  direct_reference         1.0   25.000000    1.0    202.47130     5061.78
# 155              Bobigny      Automate     AUPR48  direct_reference         1.0    0.000000    1.0     91.39855        0.00
# 156              Bobigny       PAU/TSE   RAU-PN03  direct_reference         4.0    1.000000    1.0   2625.97000    10503.88
# 157              Bobigny       PAU/TSE   TSE-PN03  direct_reference         4.0    1.000000    1.0   1259.54000     5038.16
# 158              Bobigny      Onduleur     ONP001  direct_reference         1.0    5.000000    1.0    304.01000     1520.05
# 159              Bobigny      Onduleur     ONP002  direct_reference         1.0    0.000000    1.0    337.95000        0.00
# 160              Bobigny      Onduleur     ONP003  direct_reference         1.0    0.000000    1.0    371.88000        0.00
# 161              Bobigny      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 162              Bobigny      Onduleur     ONP005  direct_reference         0.5    5.000000    1.0    414.30000     1035.75
# 163              Bobigny     Détection     DEP013             div_2         4.0    2.000000    0.5   6840.75000    27363.00
# 164              Bobigny     Détection     DEP027  direct_reference         1.0    2.000000    1.0     24.15000       48.30
# 165              Bobigny     Détection     DEP101  direct_reference         1.0    1.000000    1.0    698.25000      698.25
# 166              Bobigny     Détection     DEP200  direct_reference         1.0   64.000000    1.0     33.60000     2150.40
# 167              Bobigny     Détection     DEP201  direct_reference         1.0    0.000000    1.0     21.00000        0.00
# 168              Bobigny     Détection     DEP202  direct_reference         1.0    0.000000    1.0     36.75000        0.00
# 169              Bobigny     Détection     DEP203  direct_reference         1.0    0.000000    1.0     15.75000        0.00
# 170              Bobigny     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 171              Bobigny     Détection     DEP205  direct_reference         1.0   10.000000    1.0     26.25000      262.50
# 172              Bobigny     Détection     DEP206  direct_reference         1.0   26.000000    1.0     15.75000      409.50
# 173              Bobigny   Ventilation     VPN201             div_2         1.0    1.000000    0.5  39474.35000    19737.17
# 174              Bobigny   Ventilation     VPT300  direct_reference         1.0   30.000000    1.0     78.85000     2365.50
# 175              Bobigny   Ventilation     VPT301  direct_reference         1.0    0.000000    1.0    128.27000        0.00
# 176              Bobigny   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 177              Bobigny   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 178              Bobigny   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 179              Bobigny         Vidéo  VI MP 108             sum_2         1.0    1.000000    1.0   4234.36000     4234.36
# 180              Bobigny         Vidéo  VI MP 109             sum_2         1.0    1.000000    1.0   4234.36000     4234.36
# 181              Bobigny         Vidéo  VI MP 308             sum_2         2.0    1.000000    1.0   3174.60000     6349.20
# 182              Bobigny         Vidéo  VI MP 309             sum_2         2.0    1.000000    1.0   3174.60000     6349.20
# 183              Bobigny         Vidéo  VI MP 404  direct_reference         1.0    1.000000    1.0    263.92000      263.92
# 184              Bobigny       Pompage     INP105  direct_reference         1.0    1.000000    1.0   2910.00000     2910.00
# 185              Bobigny       Pompage       None      direct_value         3.0    0.000000    1.0      0.00000        0.00
# 186              Bobigny       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 187              Bobigny       Pompage     POE701  direct_reference         1.0    4.000000    1.0      0.00000        0.00
# 188              Bobigny       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 189              Bobigny       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 190              Bobigny       Pompage     INP700  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 191              Bobigny       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 192              Bobigny       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 193              Bobigny       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
# 194         La Courneuve      Bâtiment     VJN001             sum_2         6.0    0.333333    1.0   2029.00000     4058.00
# 195         La Courneuve      Bâtiment     VJN002             sum_2         6.0    0.333333    1.0   2029.00000     4058.00
# 196         La Courneuve      Bâtiment     VNN001             sum_2         6.0    0.333333    1.0   3264.00000     6528.00
# 197         La Courneuve      Bâtiment     VNN002             sum_2         6.0    0.333333    1.0   3264.00000     6528.00
# 198         La Courneuve      Bâtiment     MPN001             sum_2         1.0    0.333333    1.0   3519.00000     1173.00
# 199         La Courneuve      Bâtiment     MPN002             sum_2         1.0    0.333333    1.0   3519.00000     1173.00
# 200         La Courneuve      Propreté     POL013  direct_reference         2.0    2.000000    1.0   6922.20000    27688.80
# 201         La Courneuve       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 202         La Courneuve       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 203         La Courneuve       ContReg     CRN106  direct_reference         1.0    1.000000    1.0    324.30000      324.30
# 204         La Courneuve       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 205         La Courneuve       ContReg     CRC102  direct_reference         1.0    0.000000    1.0    864.80000        0.00
# 206         La Courneuve       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 207         La Courneuve     Eclairage     ECPN04  direct_reference         2.0    2.000000    1.0    162.90000      651.60
# 208         La Courneuve     Eclairage     ECPN16  direct_reference         2.0    2.000000    1.0   3459.49000    13837.96
# 209         La Courneuve     Eclairage     ECPN61             sum_3         0.4    2.000000    1.0   9242.47000     7393.98
# 210         La Courneuve     Eclairage     ECPN62             sum_3         0.4    2.000000    1.0   2378.58000     1902.86
# 211         La Courneuve     Eclairage     ECPN63             sum_3         0.4    2.000000    1.0   5436.75000     4349.40
# 212         La Courneuve           AEV     AEFN12  direct_reference         2.0    2.000000    1.0    397.62000     1590.48
# 213         La Courneuve           AEV     AEPN22  direct_reference         2.0    2.000000    1.0    810.41000     3241.64
# 214         La Courneuve           AEV      AEV08  direct_reference         1.0    4.000000    1.0     61.70000      246.80
# 215         La Courneuve      Automate     AUPR41  direct_reference         1.0    1.000000    1.0    320.77594      320.78
# 216         La Courneuve      Automate     AUPR42  direct_reference         1.0    1.000000    1.0    346.69832      346.70
# 217         La Courneuve      Automate     AUPR47  direct_reference         1.0    0.000000    1.0    202.47130        0.00
# 218         La Courneuve      Automate     AUPR48  direct_reference         1.0    0.000000    1.0     91.39855        0.00
# 219         La Courneuve       PAU/TSE   RAU-PN04  direct_reference         4.0    1.000000    1.0    337.92000     1351.68
# 220         La Courneuve       PAU/TSE   TSE-PN04  direct_reference         4.0    1.000000    1.0    134.95000      539.80
# 221         La Courneuve      Onduleur     ONP001  direct_reference         1.0    1.000000    1.0    304.01000      304.01
# 222         La Courneuve      Onduleur     ONP002  direct_reference         1.0    0.000000    1.0    337.95000        0.00
# 223         La Courneuve      Onduleur     ONP003  direct_reference         1.0    0.000000    1.0    371.88000        0.00
# 224         La Courneuve      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 225         La Courneuve      Onduleur     ONP005  direct_reference         0.5    1.000000    1.0    414.30000      207.15
# 226         La Courneuve     Détection       None      direct_value         4.0    2.000000    1.0      0.00000        0.00
# 227         La Courneuve     Détection     DEP027  direct_reference         1.0    3.000000    1.0     24.15000       72.45
# 228         La Courneuve     Détection     DEP100  direct_reference         1.0    1.000000    1.0    347.55000      347.55
# 229         La Courneuve     Détection     DEP200  direct_reference         1.0    9.000000    1.0     33.60000      302.40
# 230         La Courneuve     Détection     DEP201  direct_reference         1.0    0.000000    1.0     21.00000        0.00
# 231         La Courneuve     Détection     DEP202  direct_reference         1.0    0.000000    1.0     36.75000        0.00
# 232         La Courneuve     Détection     DEP203  direct_reference         1.0    0.000000    1.0     15.75000        0.00
# 233         La Courneuve     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 234         La Courneuve     Détection     DEP205  direct_reference         1.0    3.000000    1.0     26.25000       78.75
# 235         La Courneuve     Détection     DEP206  direct_reference         1.0    2.000000    1.0     15.75000       31.50
# 236         La Courneuve   Ventilation       None      direct_value         1.0    1.000000    1.0      0.00000        0.00
# 237         La Courneuve   Ventilation     VPT300  direct_reference         1.0    0.000000    1.0     78.85000        0.00
# 238         La Courneuve   Ventilation     VPT301  direct_reference         1.0    0.000000    1.0    128.27000        0.00
# 239         La Courneuve   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 240         La Courneuve   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 241         La Courneuve   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 242         La Courneuve         Vidéo  VI MP 112             sum_2         1.0    1.000000    1.0   1785.45000     1785.45
# 243         La Courneuve         Vidéo  VI MP 113             sum_2         1.0    1.000000    1.0   1785.45000     1785.45
# 244         La Courneuve         Vidéo  VI MP 312             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 245         La Courneuve         Vidéo  VI MP 313             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 246         La Courneuve         Vidéo  VI MP 406  direct_reference         1.0    1.000000    1.0     46.56000       46.56
# 247         La Courneuve       Pompage     INP102  direct_reference         1.0    1.000000    1.0    613.00000      613.00
# 248         La Courneuve       Pompage       None      direct_value         3.0    1.000000    1.0      0.00000        0.00
# 249         La Courneuve       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 250         La Courneuve       Pompage     POE701  direct_reference         1.0    0.000000    1.0      0.00000        0.00
# 251         La Courneuve       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 252         La Courneuve       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 253         La Courneuve       Pompage     INP700  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 254         La Courneuve       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 255         La Courneuve       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 256         La Courneuve       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
# 257                 Orly      Bâtiment     VJS005  direct_reference         6.0    1.000000    1.0    507.00000     3042.00
# 258                 Orly      Bâtiment     VNS005  direct_reference         6.0    1.000000    1.0   1306.00000     7836.00
# 259                 Orly      Bâtiment     MPS005  direct_reference         1.0    1.000000    1.0   1407.00000     1407.00
# 260                 Orly      Propreté     POL020  direct_reference         2.0    2.000000    1.0   4786.98000    19147.92
# 261                 Orly       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 262                 Orly       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 263                 Orly       ContReg     CRS110  direct_reference         1.0    1.000000    1.0    216.20000      216.20
# 264                 Orly       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 265                 Orly       ContReg     CRC102  direct_reference         1.0    0.000000    1.0    864.80000        0.00
# 266                 Orly       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 267                 Orly     Eclairage     ECPS03  direct_reference         2.0    2.000000    1.0    240.68000      962.72
# 268                 Orly     Eclairage     ECPS14  direct_reference         2.0    2.000000    1.0   3686.35000    14745.40
# 269                 Orly     Eclairage     ECPS56             sum_3         0.4    2.000000    1.0   3177.08000     2541.66
# 270                 Orly     Eclairage     ECPS57             sum_3         0.4    2.000000    1.0   2106.74000     1685.39
# 271                 Orly     Eclairage     ECPS58             sum_3         0.4    2.000000    1.0  16344.19000    13075.35
# 272                 Orly           AEV     AEFS12  direct_reference         2.0    2.000000    1.0    385.57000     1542.28
# 273                 Orly           AEV     AEPS22  direct_reference         2.0    2.000000    1.0    802.22000     3208.88
# 274                 Orly           AEV      AEV08  direct_reference         1.0   12.000000    1.0     61.70000      740.40
# 275                 Orly      Automate     AUPR25  direct_reference         1.0    1.000000    1.0    295.32920      295.33
# 276                 Orly      Automate     AUPR02  direct_reference         1.0    1.000000    1.0    360.05948      360.06
# 277                 Orly      Automate     AUPR03  direct_reference         1.0    0.000000    1.0    976.14300        0.00
# 278                 Orly      Automate     AUPR48  direct_reference         1.0    0.000000    1.0     91.39855        0.00
# 279                 Orly       PAU/TSE   RAU-PS03  direct_reference         4.0    1.000000    1.0    700.25000     2801.00
# 280                 Orly       PAU/TSE   TSE-PS03  direct_reference         4.0    1.000000    1.0     89.96000      359.84
# 281                 Orly      Onduleur     ONP001  direct_reference         1.0    0.000000    1.0    304.01000        0.00
# 282                 Orly      Onduleur     ONP002  direct_reference         1.0    1.000000    1.0    337.95000      337.95
# 283                 Orly      Onduleur     ONP003  direct_reference         1.0    0.000000    1.0    371.88000        0.00
# 284                 Orly      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 285                 Orly      Onduleur     ONP005  direct_reference         0.5    0.000000    1.0    414.30000        0.00
# 286                 Orly     Détection     DEP021  direct_reference         4.0    1.000000    1.0   2903.25000    11613.00
# 287                 Orly     Détection     DEP027  direct_reference         1.0    3.000000    1.0     24.15000       72.45
# 288                 Orly     Détection     DEP100  direct_reference         1.0    1.000000    1.0    347.55000      347.55
# 289                 Orly     Détection     DEP200  direct_reference         1.0    0.000000    1.0     33.60000        0.00
# 290                 Orly     Détection     DEP201  direct_reference         1.0    0.000000    1.0     21.00000        0.00
# 291                 Orly     Détection     DEP202  direct_reference         1.0    0.000000    1.0     36.75000        0.00
# 292                 Orly     Détection     DEP203  direct_reference         1.0   20.000000    1.0     15.75000      315.00
# 293                 Orly     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 294                 Orly     Détection     DEP205  direct_reference         1.0    0.000000    1.0     26.25000        0.00
# 295                 Orly     Détection     DEP206  direct_reference         1.0   11.000000    1.0     15.75000      173.25
# 296                 Orly   Ventilation       None      direct_value         1.0    1.000000    1.0      0.00000        0.00
# 297                 Orly   Ventilation     VPT300  direct_reference         1.0   12.000000    1.0     78.85000      946.20
# 298                 Orly   Ventilation     VPT301  direct_reference         1.0    9.000000    1.0    128.27000     1154.43
# 299                 Orly   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 300                 Orly   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 301                 Orly   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 302                 Orly         Vidéo  VI MP 142             sum_2         1.0    1.000000    1.0   3341.64000     3341.64
# 303                 Orly         Vidéo  VI MP 143             sum_2         1.0    1.000000    1.0   1785.45000     1785.45
# 304                 Orly         Vidéo  VI MP 342             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 305                 Orly         Vidéo  VI MP 343             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 306                 Orly         Vidéo  VI MP 421  direct_reference         1.0    1.000000    1.0     31.01000       31.01
# 307                 Orly       Pompage     INP403  direct_reference         1.0    1.000000    1.0   1922.00000     1922.00
# 308                 Orly       Pompage       None      direct_value         3.0    1.000000    1.0      0.00000        0.00
# 309                 Orly       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 310                 Orly       Pompage     POE701  direct_reference         1.0    0.000000    1.0      0.00000        0.00
# 311                 Orly       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 312                 Orly       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 313                 Orly       Pompage     INP700  direct_reference         1.0    9.000000    1.0    214.65000     1931.85
# 314                 Orly       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 315                 Orly       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 316                 Orly       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
# 317             Fontenay      Bâtiment     VJO004             sum_2         6.0    2.000000    1.0    507.00000     6084.00
# 318             Fontenay      Bâtiment     VJO005             sum_2         6.0    2.000000    1.0    507.00000     6084.00
# 319             Fontenay      Bâtiment     VNO004             sum_2         6.0    2.000000    1.0   1306.00000    15672.00
# 320             Fontenay      Bâtiment     VNO005             sum_2         6.0    2.000000    1.0   1306.00000    15672.00
# 321             Fontenay      Bâtiment     MPO004             sum_2         1.0    2.000000    1.0   1407.00000     2814.00
# 322             Fontenay      Bâtiment     MPO005             sum_2         1.0    2.000000    1.0   1407.00000     2814.00
# 323             Fontenay      Propreté     POL002  direct_reference         2.0    2.000000    1.0   7700.59000    30802.36
# 324             Fontenay       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 325             Fontenay       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 326             Fontenay       ContReg     CRO122  direct_reference         1.0    1.000000    1.0    432.40000      432.40
# 327             Fontenay       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 328             Fontenay       ContReg     CRC102  direct_reference         1.0    0.000000    1.0    864.80000        0.00
# 329             Fontenay       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 330             Fontenay     Eclairage     ECPB03  direct_reference         2.0    2.000000    1.0    162.90000      651.60
# 331             Fontenay     Eclairage     ECPB14  direct_reference         2.0    2.000000    1.0   3265.72000    13062.88
# 332             Fontenay     Eclairage     ECPB57             sum_3         0.4    2.000000    1.0   3058.17000     2446.54
# 333             Fontenay     Eclairage     ECPB58             sum_3         0.4    2.000000    1.0   3024.20000     2419.36
# 334             Fontenay     Eclairage     ECPB59             sum_3         0.4    2.000000    1.0   5657.62000     4526.10
# 335             Fontenay           AEV     AEFB12  direct_reference         2.0    2.000000    1.0    397.62000     1590.48
# 336             Fontenay           AEV     AEPB12  direct_reference         2.0    2.000000    1.0    794.03000     3176.12
# 337             Fontenay           AEV      AEV08  direct_reference         1.0   16.000000    1.0     61.70000      987.20
# 338             Fontenay      Automate     AUPR17  direct_reference         1.0    1.000000    1.0    320.77594      320.78
# 339             Fontenay      Automate     AUPR18  direct_reference         1.0    1.000000    1.0    711.42772      711.43
# ...
# 1518             Bicêtre      Bâtiment     VNS001             div_2         6.0    2.000000    0.5   1306.00000     7836.00
# 1519             Bicêtre      Bâtiment     VNS002             div_2         6.0    2.000000    0.5   1306.00000     7836.00
# 1520             Bicêtre      Bâtiment     MPS001             div_2         1.0    2.000000    0.5   1407.00000     1407.00
# 1521             Bicêtre      Bâtiment     MPS002             div_2         1.0    2.000000    0.5   1407.00000     1407.00
# 1522             Bicêtre      Propreté     POL018  direct_reference         2.0    2.000000    1.0   8670.61000    34682.44
# 1523             Bicêtre       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 1524             Bicêtre       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 1525             Bicêtre       ContReg     CRS107             sum_2         1.0    1.000000    1.0    864.80000      864.80
# 1526             Bicêtre       ContReg     CRS108             sum_2         1.0    1.000000    1.0    864.80000      864.80
# 1527             Bicêtre       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 1528             Bicêtre       ContReg     CRC102  direct_reference         1.0    0.000000    1.0    864.80000        0.00
# 1529             Bicêtre       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 1530             Bicêtre     Eclairage     ECPS01  direct_reference         2.0    2.000000    1.0    407.24000     1628.96
# 1531             Bicêtre     Eclairage     ECPS10  direct_reference         2.0    2.000000    1.0   5449.18000    21796.72
# 1532             Bicêtre     Eclairage     ECPS50             sum_3         0.4    2.000000    1.0   7696.40000     6157.12
# 1533             Bicêtre     Eclairage     ECPS51             sum_3         0.4    2.000000    1.0   5470.71000     4376.57
# 1534             Bicêtre     Eclairage     ECPS52             sum_3         0.4    2.000000    1.0  23921.68000    19137.34
# 1535             Bicêtre           AEV     AEFS10  direct_reference         2.0    2.000000    1.0    714.56000     2858.24
# 1536             Bicêtre           AEV     AEPS20  direct_reference         2.0    2.000000    1.0   2096.07000     8384.28
# 1537             Bicêtre           AEV      AEV08  direct_reference         1.0   22.000000    1.0     61.70000     1357.40
# 1538             Bicêtre      Automate     AUPR23             div_2         1.0    1.000000    0.5    346.22268      173.11
# 1539             Bicêtre      Automate     AUPR24             div_2         1.0    1.000000    0.5   1871.29748      935.65
# 1540             Bicêtre      Automate     AUPR47  direct_reference         1.0    3.000000    1.0    202.47130      607.41
# 1541             Bicêtre      Automate     AUPR48  direct_reference         1.0    0.000000    1.0     91.39855        0.00
# 1542             Bicêtre       PAU/TSE   RAU-PS02             div_2         4.0    1.000000    0.5   2208.71000     4417.42
# 1543             Bicêtre       PAU/TSE   TSE-PS02             div_2         4.0    1.000000    0.5    584.79000     1169.58
# 1544             Bicêtre      Onduleur     ONP001  direct_reference         1.0    0.000000    1.0    304.01000        0.00
# 1545             Bicêtre      Onduleur     ONP002  direct_reference         1.0    2.000000    1.0    337.95000      675.90
# 1546             Bicêtre      Onduleur     ONP003  direct_reference         1.0    0.000000    1.0    371.88000        0.00
# 1547             Bicêtre      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 1548             Bicêtre      Onduleur     ONP005  direct_reference         0.5    0.000000    1.0    414.30000        0.00
# 1549             Bicêtre     Détection     DEP019  direct_reference         4.0    2.000000    1.0   6303.15000    50425.20
# 1550             Bicêtre     Détection     DEP027  direct_reference         1.0    4.000000    1.0     24.15000       96.60
# 1551             Bicêtre     Détection     DEP100  direct_reference         1.0    1.000000    1.0    347.55000      347.55
# 1552             Bicêtre     Détection     DEP200  direct_reference         1.0   44.000000    1.0     33.60000     1478.40
# 1553             Bicêtre     Détection     DEP201  direct_reference         1.0   45.000000    1.0     21.00000      945.00
# 1554             Bicêtre     Détection     DEP202  direct_reference         1.0    3.000000    1.0     36.75000      110.25
# 1555             Bicêtre     Détection     DEP203  direct_reference         1.0    0.000000    1.0     15.75000        0.00
# 1556             Bicêtre     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 1557             Bicêtre     Détection     DEP205  direct_reference         1.0    0.000000    1.0     26.25000        0.00
# 1558             Bicêtre     Détection     DEP206  direct_reference         1.0    2.000000    1.0     15.75000       31.50
# 1559             Bicêtre   Ventilation     VPS202  direct_reference         1.0    1.000000    1.0   9212.68000     9212.68
# 1560             Bicêtre   Ventilation     VPT300  direct_reference         1.0    2.000000    1.0     78.85000      157.70
# 1561             Bicêtre   Ventilation     VPT301  direct_reference         1.0    0.000000    1.0    128.27000        0.00
# 1562             Bicêtre   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 1563             Bicêtre   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 1564             Bicêtre   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 1565             Bicêtre         Vidéo  VI MP 140             div_2         1.0    1.000000    0.5   3341.64000     1670.82
# 1566             Bicêtre         Vidéo  VI MP 141             div_2         1.0    1.000000    0.5   3341.64000     1670.82
# 1567             Bicêtre         Vidéo  VI MP 340             div_2         2.0    1.000000    0.5   1696.19000     1696.19
# 1568             Bicêtre         Vidéo  VI MP 341             div_2         2.0    1.000000    0.5   1696.19000     1696.19
# 1569             Bicêtre         Vidéo  VI MP 420             div_2         1.0    1.000000    0.5    201.81000      100.91
# 1570             Bicêtre       Pompage     INP405  direct_reference         1.0    1.000000    1.0   2402.00000     2402.00
# 1571             Bicêtre       Pompage     POP403             sum_2         3.0    1.000000    1.0    858.61000     2575.83
# 1572             Bicêtre       Pompage     POP404             sum_2         3.0    1.000000    1.0    858.61000     2575.83
# 1573             Bicêtre       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 1574             Bicêtre       Pompage     POP403             sum_2         1.0    2.000000    1.0    858.61000     1717.22
# 1575             Bicêtre       Pompage     POP404             sum_2         1.0    2.000000    1.0    858.61000     1717.22
# 1576             Bicêtre       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 1577             Bicêtre       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 1578             Bicêtre       Pompage     INP700  direct_reference         1.0   12.000000    1.0    214.65000     2575.80
# 1579             Bicêtre       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 1580             Bicêtre       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 1581             Bicêtre       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
# 1582           Champigny      Bâtiment     VJE003             sum_2         6.0    1.000000    1.0   1014.00000     6084.00
# 1583           Champigny      Bâtiment     VJE004             sum_2         6.0    1.000000    1.0   1014.00000     6084.00
# 1584           Champigny      Bâtiment     VNE003             sum_2         6.0    1.000000    1.0   1958.00000    11748.00
# 1585           Champigny      Bâtiment     VNE004             sum_2         6.0    1.000000    1.0   1958.00000    11748.00
# 1586           Champigny      Bâtiment     MPE003             sum_2         1.0    1.000000    1.0   2111.00000     2111.00
# 1587           Champigny      Bâtiment     MPE004             sum_2         1.0    1.000000    1.0   2111.00000     2111.00
# 1588           Champigny      Propreté     POL015  direct_reference         2.0    2.000000    1.0  12869.64000    51478.56
# 1589           Champigny       ContReg     CRC106  direct_reference         1.0    1.000000    1.0    486.45000      486.45
# 1590           Champigny       ContReg     CRC107  direct_reference         1.0    1.000000    1.0    864.80000      864.80
# 1591           Champigny       ContReg     CRE103             sum_2         1.0    1.000000    1.0   1081.00000     1081.00
# 1592           Champigny       ContReg     CRE104             sum_2         1.0    1.000000    1.0   1081.00000     1081.00
# 1593           Champigny       ContReg     CRC101  direct_reference         1.0    0.000000    1.0    648.60000        0.00
# 1594           Champigny       ContReg     CRC102  direct_reference         1.0    0.000000    1.0    864.80000        0.00
# 1595           Champigny       ContReg     CRC103  direct_reference         1.0    0.000000    1.0   1081.00000        0.00
# 1596           Champigny     Eclairage     ECPE03  direct_reference         2.0    2.000000    1.0    529.42000     2117.68
# 1597           Champigny     Eclairage     ECPE14  direct_reference         2.0    2.000000    1.0  10577.37000    42309.48
# 1598           Champigny     Eclairage     ECPE58             sum_3         0.4    2.000000    1.0  20047.99000    16038.39
# 1599           Champigny     Eclairage     ECPE60             sum_3         0.4    2.000000    1.0  14679.21000    11743.37
# 1600           Champigny     Eclairage     ECPE61             sum_3         0.4    2.000000    1.0  13353.99000    10683.19
# 1601           Champigny           AEV     AEFE12  direct_reference         2.0    2.000000    1.0    801.05000     3204.20
# 1602           Champigny           AEV     AEPE22  direct_reference         2.0    2.000000    1.0   2376.93000     9507.72
# 1603           Champigny           AEV      AEV08  direct_reference         1.0   18.000000    1.0     61.70000     1110.60
# 1604           Champigny      Automate     AUPR29  direct_reference         1.0    1.000000    1.0    371.65861      371.66
# 1605           Champigny      Automate     AUPR30  direct_reference         1.0    1.000000    1.0   1152.14061     1152.14
# 1606           Champigny      Automate     AUPR47  direct_reference         1.0    2.000000    1.0    202.47130      404.94
# 1607           Champigny      Automate     AUPR48  direct_reference         1.0    0.000000    1.0     91.39855        0.00
# 1608           Champigny       PAU/TSE   RAU-PE02  direct_reference         4.0    1.000000    1.0   1520.65000     6082.60
# 1609           Champigny       PAU/TSE   TSE-PE02  direct_reference         4.0    1.000000    1.0    494.83000     1979.32
# 1610           Champigny      Onduleur     ONP001  direct_reference         1.0    0.000000    1.0    304.01000        0.00
# 1611           Champigny      Onduleur     ONP002  direct_reference         1.0    0.000000    1.0    337.95000        0.00
# 1612           Champigny      Onduleur     ONP003  direct_reference         1.0    2.000000    1.0    371.88000      743.76
# 1613           Champigny      Onduleur     ONP004  direct_reference         1.0    0.000000    1.0    185.94000        0.00
# 1614           Champigny      Onduleur     ONP005  direct_reference         0.5    2.000000    1.0    414.30000      414.30
# 1615           Champigny     Détection     DEP015  direct_reference         4.0    2.000000    1.0   3202.50000    25620.00
# 1616           Champigny     Détection     DEP027  direct_reference         1.0    3.000000    1.0     24.15000       72.45
# 1617           Champigny     Détection     DEP100  direct_reference         1.0    1.000000    1.0    347.55000      347.55
# 1618           Champigny     Détection     DEP200  direct_reference         1.0   43.000000    1.0     33.60000     1444.80
# 1619           Champigny     Détection     DEP201  direct_reference         1.0    0.000000    1.0     21.00000        0.00
# 1620           Champigny     Détection     DEP202  direct_reference         1.0    0.000000    1.0     36.75000        0.00
# 1621           Champigny     Détection     DEP203  direct_reference         1.0   10.000000    1.0     15.75000      157.50
# 1622           Champigny     Détection     DEP204  direct_reference         1.0    0.000000    1.0     23.10000        0.00
# 1623           Champigny     Détection     DEP205  direct_reference         1.0    7.000000    1.0     26.25000      183.75
# 1624           Champigny     Détection     DEP206  direct_reference         1.0    9.000000    1.0     15.75000      141.75
# 1625           Champigny   Ventilation     VPE201  direct_reference         1.0    1.000000    1.0   5585.14000     5585.14
# 1626           Champigny   Ventilation     VPT300  direct_reference         1.0    4.000000    1.0     78.85000      315.40
# 1627           Champigny   Ventilation     VPT301  direct_reference         1.0    6.000000    1.0    128.27000      769.62
# 1628           Champigny   Ventilation     VPT302  direct_reference         1.0    0.000000    1.0    449.49000        0.00
# 1629           Champigny   Ventilation     VPT304  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 1630           Champigny   Ventilation     VPT305  direct_reference         1.0    0.000000    1.0     12.58000        0.00
# 1631           Champigny         Vidéo  VI MP 100             sum_2         1.0    1.000000    1.0   3341.64000     3341.64
# 1632           Champigny         Vidéo  VI MP 101             sum_2         1.0    1.000000    1.0   3341.64000     3341.64
# 1633           Champigny         Vidéo  VI MP 300             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 1634           Champigny         Vidéo  VI MP 301             sum_2         2.0    1.000000    1.0   1696.19000     3392.38
# 1635           Champigny         Vidéo  VI MP 400  direct_reference         1.0    1.000000    1.0    201.81000      201.81
# 1636           Champigny       Pompage     INP203  direct_reference         1.0    1.000000    1.0   2590.00000     2590.00
# 1637           Champigny       Pompage       None      direct_value         3.0    1.000000    1.0      0.00000        0.00
# 1638           Champigny       Pompage     POE600  direct_reference         1.0    0.000000    1.0    572.06000        0.00
# 1639           Champigny       Pompage       None      direct_value         1.0    0.000000    1.0      0.00000        0.00
# 1640           Champigny       Pompage     INP500  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 1641           Champigny       Pompage     INP600  direct_reference         1.0    0.000000    1.0    858.61000        0.00
# 1642           Champigny       Pompage     INP700  direct_reference         1.0    4.000000    1.0    214.65000      858.60
# 1643           Champigny       Pompage     INP800  direct_reference         1.0    0.000000    1.0    214.65000        0.00
# 1644           Champigny       Pompage     INP900  direct_reference         1.0    0.000000    1.0    208.40000        0.00
# 1645           Champigny       Pompage     INP901  direct_reference         1.0    0.000000    1.0    714.81000        0.00
#
# Skipped rows summary (only for rows with marchés in target list):
# Total skipped rows: 0

# %%
df.groupby('tunnel')['cout_total'].sum()
# Out:
# tunnel
# Ambroise Paré          227419.93
# Antony                 150926.14
# Belle-Rive             284358.03
# Bicêtre                219212.70
# Bobigny                274904.34
# Boissy                 157750.30
# Champigny              254497.57
# Chennevières           122960.62
# Fontenay               156008.04
# Fresnes                165767.49
# Guy Môquet             178913.54
# Italie                  78171.13
# La Courneuve           101015.06
# La Défense            1130110.88
# Landy                  305631.10
# Lumen-Norton           203176.21
# Moulin                 180645.57
# Nanterre Centre        308494.37
# Nanterre échangeur     484508.68
# Neuilly                124335.58
# Nogent                 442966.85
# Orly                   106075.22
# Saint-Cloud            230813.48
# Sévines                118078.62
# Taverny                135365.62
# Name: cout_total, dtype: float64

# %% [markdown]
# Maintenant, on veut rajouter les prdp_code (codes prix permanents) à ce table.

# %%
csv_url = 'https://raw.githubusercontent.com/mission-donnees-dett/analyse_preventifs_23_25/main/prdp_prod_code_montants_designation_2324.csv'
df_csv = pd.read_csv(csv_url, delimiter=';')

mapping = dict(zip(df_csv['prod_code'], df_csv['prdp_code']))

df['prdp_code'] = df['ref_prix'].map(mapping)

ref_prix_index = df.columns.get_loc('ref_prix')
cols = df.columns.tolist()
cols.insert(ref_prix_index, cols.pop(cols.index('prdp_code')))
df = df[cols]

# %%
#df.to_csv('coutTunnelsPreventifs_parPrix.csv')
